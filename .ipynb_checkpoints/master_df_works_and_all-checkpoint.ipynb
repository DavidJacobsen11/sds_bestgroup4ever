# %%
### We create our log file

# %%
## %matplotlib inline
import matplotlib.pyplot as plt
import requests, re, time
from bs4 import BeautifulSoup
import scraping_class
import pprint
import pandas as pd
import numpy as np
import pickle
logfile = 'the_log.csv'## name your log file.
connector = scraping_class.Connector(logfile)
session = requests.session()
session.headers['mkp244@alumni.ku.dk'] = 'mkp244@alumni.ku.dk' 
session.headers['Oluf Kelkjær'] = 'Oluf Kelkjær'
session.headers
# Out:
# {'User-Agent': 'python-requests/2.21.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'mkp244@alumni.ku.dk': 'mkp244@alumni.ku.dk', 'Oluf Kelkjær': 'Oluf Kelkjær'}

# %%
import requests

# %%
url=[]
for n in range (1,5251,250):
    url.append('https://www.imdb.com/search/title/?title_type=feature&num_votes=20000,&sort=moviemeter,desc&count=250&start=' + str(n) + '&ref_=adv_nxt')
   


links = []
import time
for x in url:
    time.sleep(0.5)
    response = requests.get(x)
    if response.ok:
        html = response.text
    else:
        print('error')
    BeautifulSoup(html,'html.parser')
    link_location = html.split('href="')[1:]
    


    for link_loc in link_location:
        link = link_loc.split('"')[0].strip('title_type')      #-> check om det kan ekskluderes bagefter
        if '/title/' in link:
            links.append(link) 


links = ['https://www.imdb.com/'+link for link in links if not 'plotsummar' in link and not 'title_type' in link and not 'ref' in link and not 'plotsummary' in link and not 'vote' in link] # add the domain to each link
links=set(links)
links
# Out:
# {'https://www.imdb.com//title/tt0088993/',
#  'https://www.imdb.com//title/tt1034389/',
#  'https://www.imdb.com//title/tt7282468/',
#  'https://www.imdb.com//title/tt0405336/',
#  'https://www.imdb.com//title/tt0082971/',
#  'https://www.imdb.com//title/tt0758766/',
#  'https://www.imdb.com//title/tt1436045/',
#  'https://www.imdb.com//title/tt1496025/',
#  'https://www.imdb.com//title/tt0312004/',
#  'https://www.imdb.com//title/tt1231580/',
#  'https://www.imdb.com//title/tt0443465/',
#  'https://www.imdb.com//title/tt0388473/',
#  'https://www.imdb.com//title/tt3521126/',
#  'https://www.imdb.com//title/tt0329028/',
#  'https://www.imdb.com//title/tt1323594/',
#  'https://www.imdb.com//title/tt0112760/',
#  'https://www.imdb.com//title/tt0450278/',
#  'https://www.imdb.com//title/tt0223897/',
#  'https://www.imdb.com//title/tt0457495/',
#  'https://www.imdb.com//title/tt0071129/',
#  'https://www.imdb.com//title/tt0077651/',
#  'https://www.imdb.com//title/tt0096061/',
#  'https://www.imdb.com//title/tt0119345/',
#  'https://www.imdb.com//title/tt0107387/',
#  'https://www.imdb.com//title/tt2097298/',
#  'https://www.imdb.com//title/tt0413267/',
#  'https://www.imdb.com//title/tt0106308/',
#  'https://www.imdb.com//title/tt0375173/',
#  'https://www.imdb.com//title/tt0270053/',
#  'https://www.imdb.com//title/tt0085334/',
#  'https://www.imdb.com//title/tt0085382/',
#  'https://www.imdb.com//title/tt0134119/',
#  'https://www.imdb.com//title/tt1713476/',
#  'https://www.imdb.com//title/tt0111255/',
#  'https://www.imdb.com//title/tt0105265/',
#  'https://www.imdb.com//title/tt0121765/',
#  'https://www.imdb.com//title/tt1174732/',
#  'https://www.imdb.com//title/tt0150377/',
#  'https://www.imdb.com//title/tt2490326/',
#  'https://www.imdb.com//title/tt0970416/',
#  'https://www.imdb.com//title/tt0890870/',
#  'https://www.imdb.com//title/tt0074486/',
#  'https://www.imdb.com//title/tt0381061/',
#  'https://www.imdb.com//title/tt6217306/',
#  'https://www.imdb.com//title/tt0080516/',
#  'https://www.imdb.com//title/tt1166100/',
#  'https://www.imdb.com//title/tt1019452/',
#  'https://www.imdb.com//title/tt0387808/',
#  'https://www.imdb.com//title/tt0031679/',
#  'https://www.imdb.com//title/tt0138510/',
#  'https://www.imdb.com//title/tt0120601/',
#  'https://www.imdb.com//title/tt0971209/',
#  'https://www.imdb.com//title/tt2975590/',
#  'https://www.imdb.com//title/tt0124819/',
#  'https://www.imdb.com//title/tt0120735/',
#  'https://www.imdb.com//title/tt0114781/',
#  'https://www.imdb.com//title/tt0097202/',
#  'https://www.imdb.com//title/tt0352248/',
#  'https://www.imdb.com//title/tt0306047/',
#  'https://www.imdb.com//title/tt0323944/',
#  'https://www.imdb.com//title/tt0104573/',
#  'https://www.imdb.com//title/tt1588334/',
#  'https://www.imdb.com//title/tt1821593/',
#  'https://www.imdb.com//title/tt1067583/',
#  'https://www.imdb.com//title/tt0790686/',
#  'https://www.imdb.com//title/tt0089175/',
#  'https://www.imdb.com//title/tt6697582/',
#  'https://www.imdb.com//title/tt1778304/',
#  'https://www.imdb.com//title/tt0079367/',
#  'https://www.imdb.com//title/tt0068767/',
#  'https://www.imdb.com//title/tt0118571/',
#  'https://www.imdb.com//title/tt0443295/',
#  'https://www.imdb.com//title/tt0092099',
#  'https://www.imdb.com//title/tt1294226/',
#  'https://www.imdb.com//title/tt0120324/',
#  ...}

# %%
links=set(links)
len(links)
# Out:
# 5271

# %% [markdown]
# ### Parsing HTML with BeautifulSoup
#
# When parsing, we took advantage of the pyhton library BeautifulSoup.
#
# "BeautifulSoup makes the html tree navigable.
# It allows you to:
#     * Search for elements by tag name and/or by attribute.
#     * Iterate through them, go up, sideways or down the tree.
#     * Furthermore it helps you with standard tasks such as extracting raw text from html,
#     which would be a very tedious task if you had to hardcode it using `.split` commands and using your own regular expressions will be unstable."

# %%
def find_budget(soup):
    for i in soup.find(id="titleDetails").find_all("div", class_="txt-block"):
        if i.find().text == "Budget:":
            return float(i.text.strip().split("\n")[0].split("$")[1].replace(",", ""))
        
def find_gross(soup):
    for i in soup.find(id="titleDetails").find_all("div", class_="txt-block"):
        if i.find().text == "Cumulative Worldwide Gross:":
            return float(i.text.strip().split("\n")[0].split("$")[1].replace(",", ""))
        
def find_grossUSA(soup):
    for i in soup.find(id="titleDetails").find_all("div", class_="txt-block"):
        if i.find().text == "Gross USA:":
            return float(i.text.strip().split("\n")[0].split("$")[1].replace(",", ""))

def find_rating(soup):
    for i in soup.find(id="title-overview-widget").find_all("div", class_="ratingValue"):
        return float(i.text.strip().split("/")[0])
        
def find_runtime(soup):
    for i in soup.find(id="titleDetails").find_all("div", class_="txt-block"):
        if i.find().text == "Runtime:":
            return float(i.text.strip().split("\n")[1].split("min")[0].strip())
def find_date(soup):
    for i in soup.find(id="titleDetails").find_all("div", class_="txt-block"):
        if i.find().text == "Release Date:":
            return i.text.strip().split(":")[1].split("(")[0].strip()
        
def find_genre(soup):
    for i in soup.find(id="title-overview-widget").find_all("div", class_="subtext"):
        if str(i.text.strip().split("|")[2].replace('\n','').replace(' ','').split(","))[-3]==(')'):
            return i.text.strip().split("|")[1].replace('\n','').replace(' ','').split(",")
        else:
            return i.text.strip().split("|")[2].replace('\n','').replace(' ','').split(",")

# %% [markdown]
# ### Parsing and cleaning the data
#
# Here we use our earlier defined functions to make a dictionary of all the data we need from the description page of each movie, ie. title, budget, the cumulative worldwide gross, the rating, the runtime, date and genre.

# %%
def page_extractor(url):
    r, call_id = connector.get(url, "LOL")
    try:
        soup = BeautifulSoup(r.text, "html.parser")
        title = soup.select("#title-overview-widget > div.vital > div.title_block > div > div.titleBar > div.title_wrapper > h1")[0].text.split("\xa0")[0]
        budget = find_budget(soup)
        cumulative_worldwide_gross=find_gross(soup)
        gross_usa=find_grossUSA(soup)
        rating = find_rating(soup)
        runtime = find_runtime(soup)
        date= find_date(soup)
        genre = find_genre(soup)
    except:
        soup = None
        title = None
        budget = None
        cumulative_worldwide_gross= None
        gross_usa = None
        rating=None
        runtime = None
        date = None
        genre = None
    return {
        "title": title,
        #"year": year,
        "budget": budget,
        "url": url,
        "cumulative_world_gross": cumulative_worldwide_gross,
        "gross_usa": gross_usa,
        "rating": rating,
        "runtime": runtime,
        "date": date,
        "genre": genre
    }

# %% [markdown]
# ### Create a list and append information from every movie on the list.
# Remark: We have only chosen top 250 so far, as to not make the coding too slow in progress. If you wish to see the whole list, or a minor part of it, simply change the brackets after 'links'.

# %%
# res = []
# for idx, i in enumerate(links):
#     print(idx + 1, "of", len(links))
#     res.append(page_extractor(i))

# %% [markdown]
# ### Making our list into a dataframe, and applying datetime to the releasedate
#
# A dataframe is basically just when a list has both several columns and rows, if there's only one row it's an array.
#
# Remember to comment on the string lengths need to be over 4 characters.

# %%
# df = pd.DataFrame(res).dropna()

# df = df[df['date'].str.len() > 4]

# def preparedatetime(dataframe):
#     dataframe['datetime'] = pd.to_datetime(dataframe['date'], format = '%d %B %Y')
#     dataframe['year'] = dataframe.datetime.dt.year
#     dataframe['month'] = dataframe.datetime.dt.month
#     dataframe['day'] = dataframe.datetime.dt.day
#     return dataframe

# df = preparedatetime(df)
# df
# df.to_pickle('all_movies.csv') #saves relatively as csv 
#df.to_pickle('all_movies.pkl')
# #This command will load dataset from pkl or csv file
# df = pd.read_pickle('all_movies.csv')
# # or
df = pd.read_pickle('all_movies.pkl')
df
# Out:
#            budget  cumulative_world_gross               date  \
# 1     110000000.0            7.122059e+08   17 November 2011
# 2       3500000.0            1.950404e+07  29 September 2011
# 3      56600000.0            6.942439e+07    21 January 2005
# 4     175000000.0            1.734188e+08       27 July 2007
# 6       8000000.0            1.005232e+08   17 November 2006
# 7      78000000.0            1.792652e+08  26 September 2003
# 8      25000000.0            1.341196e+07        3 June 2005
# 9      14000000.0            1.434303e+07        24 May 2002
# 10     15000000.0            8.064053e+07      25 March 1988
# 12     12000000.0            5.222331e+07   29 November 2002
# 14     70000000.0            1.013710e+08       7 March 1997
# 15      9000000.0            2.784544e+08    26 January 2017
# 16    125000000.0            1.984672e+08      9 August 2012
# 17     31000000.0            1.355195e+07        16 May 2014
# 18     35000000.0            2.518293e+07      10 March 2016
# 19     26000000.0            1.810962e+08   26 December 1991
# 20     60000000.0            8.694796e+07       6 March 2009
# 21     40000000.0            4.962778e+07     23 August 1996
['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family',
#                'Fantasy', 'Film-Noir', 'Game-Show', 'History', 'Horror', 'Music', 'Musical', 'Mystery', 'News',
#                'Reality-TV', 'Romance', 'Sci-Fi', 'Sport', 'Talk-Show', 'Thriller'])
df2 = pd.concat([df, pd.DataFrame(columns=categories)], axis=1)

# %%
def df_dummy(df, col):
    return df.apply(lambda x: col in x["genre"], axis=1)

for i in categories:
    df2[i] = df_dummy(df2, i)
    df2[i] = pd.get_dummies(df2[i], drop_first = True)


df2 = df2.set_index(df['title'])
del df2['title']

df2
# Out:
#                                     budget  cumulative_world_gross  \
# title
# Breaking Dawn - del 1          110000000.0            7.122059e+08
# Giftig viden                     3500000.0            1.950404e+07
# En lang forlovelse              56600000.0            6.942439e+07
# Du almægtige, Evan             175000000.0            1.734188e+08
# Little Miss Sunshine             8000000.0            1.005232e+08
# Det hemmelighedsfulde selskab   78000000.0            1.792652e+08
# Lords of Dogtown                25000000.0            1.341196e+07
# Freddy Got Fingered             14000000.0            1.434303e+07
# Lunefulde måne                  15000000.0            8.064053e+07
# One Hour Photo                  12000000.0            5.222331e+07
# Mars Attacks                    70000000.0            1.013710e+08
# Split                            9000000.0            2.784544e+08
# Total Recall                   125000000.0            1.984672e+08
# Januar har to ansigter          31000000.0            1.355195e+07
# Grimsby                         35000000.0            2.518293e+07
# Hot Shots!                      26000000.0            1.810962e+08
# Eventyret om Despero            60000000.0            8.694796e+07
# The Island of Dr. Moreau        40000000.0            4.962778e+07
# Mig og Annie                     4000000.0            3.828718e+07
# The Ring                        48000000.0            2.493489e+08
# Antitrust                       30000000.0            1.819561e+07
# Drageløberen                    20000000.0            7.463482e+07
# Just Like Heaven                58000000.0            1.028544e+08
# På skudhold                     30000000.0            2.410787e+07
# A Serious Man                    7000000.0            3.143033e+07
# Mother's Day                    25000000.0            4.878267e+07
# The Believer                     1500000.0            1.309316e+06
# Hedwig and the Angry Inch        6000000.0            3.644200e+06
# 22 Jump Street                  50000000.0            3.313339e+08
# White House Down               150000000.0            2.053667e+08
# ...                                    ...                     ...
# What Dreams May Come            85000000.0            5.538293e+07
# The Pink Panther 2              70000000.0            7.594662e+07
# Cronos                           2000000.0            6.213920e+05
# Det skøre hold                  11000000.0            4.979715e+07
# Fish Tank                        3000000.0            2.357852e+06
# Kung Fu Panda 2                150000000.0            6.656923e+08
# Adrift                          35000000.0            5.994501e+07
# Bridget Jones' dagbog           25000000.0            2.819298e+08
# Meet the Blacks                   900000.0            9.097072e+06
# Money Talks                     25000000.0            4.840761e+07
# Quarantine                      12000000.0            4.131991e+07
# Skyfall                        200000000.0            1.108561e+09
# Min mikro-makker                27000000.0            2.589381e+07
# Værelse med udsigt               3000000.0            2.096664e+07
# Jobs                            12000000.0            3.593141e+07
# Secretariat                     35000000.0            6.025137e+07
# 300: Rise of an Empire                      [Action, Fantasy]  106580051.0
# Nu eller aldrig                               [Comedy, Drama]   93466502.0
# Smølferne 2                    [Animation, Adventure, Comedy]   71017784.0
# Stand-in for mord                     [Crime, Drama, Mystery]    8801940.0
#
#                                rating  runtime  \
# title
# Breaking Dawn - del 1             4.9    117.0
# Giftig viden                      7.1    107.0
# En lang forlovelse                7.6    133.0
# Du almægtige, Evan                5.4     96.0
# Little Miss Sunshine              7.8    101.0
# Det hemmelighedsfulde selskab     5.8    110.0
# Lords of Dogtown                  7.1    107.0
# Freddy Got Fingered               4.6     87.0
# Lunefulde måne                    7.1    102.0
# One Hour Photo                    6.8     96.0
# Mars Attacks                      6.3    106.0
# Split                             7.3    117.0
# Total Recall                      6.3    118.0
# Januar har to ansigter            6.2     96.0
# Grimsby                           6.2     83.0
# Hot Shots!                        6.8     84.0
# Eventyret om Despero              6.1     93.0
# The Island of Dr. Moreau          4.5     96.0
# Mig og Annie                      8.0     93.0
# The Ring                          7.1    115.0
# Antitrust                         6.1    105.0
# Drageløberen                      7.6    128.0
# Just Like Heaven                  6.7     95.0
# På skudhold                       5.8    102.0
# A Serious Man                     7.0    106.0
# Mother's Day                      5.7    118.0
# The Believer                      7.2     98.0
# Hedwig and the Angry Inch         7.7     95.0
# 22 Jump Street                    7.0    112.0
# White House Down                  6.4    131.0
# ...                               ...      ...
# What Dreams May Come              7.0    113.0
# The Pink Panther 2                5.6     92.0
# Cronos                            6.7     94.0
# Det skøre hold                    7.2    107.0
# Fish Tank                         7.3    123.0
# Kung Fu Panda 2                   7.2     90.0
# Adrift                            6.6     96.0
# Bridget Jones' dagbog             6.7     97.0
# Meet the Blacks                   4.9     94.0
# Money Talks                       6.2     97.0
# Quarantine                        6.0     89.0
# Skyfall                           7.7    143.0
# Min mikro-makker                  6.8    120.0
# Værelse med udsigt                7.3    117.0
# Jobs                              5.9    128.0
# Secretariat                       7.2    123.0
# Lions for Lambs                   6.2     92.0
# Gosford Park                      7.2    131.0
# The Skeleton Key                  6.5    104.0
# Frankie & Johnny                  6.7    118.0
# Kill the Irishman                 7.1    106.0
# Klienten                          6.7    119.0
# The Jacket                        7.1    103.0
# Voldens gade                      7.4    123.0
# Table 19                          5.8     87.0
# Hundehotellet                     5.4    100.0
# 300: Rise of an Empire            6.2    102.0
# Nu eller aldrig                   7.4     97.0
# Smølferne 2                       5.3    105.0
# Stand-in for mord                 6.8    114.0
#
#                                                                   url  \
# title
# Breaking Dawn - del 1          https://www.imdb.com//title/tt1324999/
# Giftig viden                   https://www.imdb.com//title/tt1615147/
# En lang forlovelse             https://www.imdb.com//title/tt0344510/
# Du almægtige, Evan             https://www.imdb.com//title/tt0413099/
# Little Miss Sunshine           https://www.imdb.com//title/tt0449059/
# Det hemmelighedsfulde selskab  https://www.imdb.com//title/tt0311429/
# Lords of Dogtown               https://www.imdb.com//title/tt0355702/
# Freddy Got Fingered            https://www.imdb.com//title/tt0240515/
# Breaking Dawn - del 1         2011-11-17  2011  ...       1          1
# Giftig viden                  2011-09-29  2011  ...       0          0
# En lang forlovelse            2005-01-21  2005  ...       0          0
# Du almægtige, Evan            2007-07-27  2007  ...       0          0
# Little Miss Sunshine          2006-11-17  2006  ...       0          0
# Det hemmelighedsfulde selskab 2003-09-26  2003  ...       1          1
# Lords of Dogtown              2005-06-03  2005  ...       0          0
# Freddy Got Fingered           2002-05-24  2002  ...       0          0
# Lunefulde måne                1988-03-25  1988  ...       0          0
# One Hour Photo                2002-11-29  2002  ...       0          0
# Mars Attacks                  1997-03-07  1997  ...       0          0
# Split                         2017-01-26  2017  ...       0          0
# Total Recall                  2012-08-09  2012  ...       1          1
# Januar har to ansigter        2014-05-16  2014  ...       0          0
# Grimsby                       2016-03-10  2016  ...       1          1
# Hot Shots!                    1991-12-26  1991  ...       1          0
# Eventyret om Despero          2009-03-06  2009  ...       0          1
# The Island of Dr. Moreau      1996-08-23  1996  ...       0          0
# Mig og Annie                  1977-07-29  1977  ...       0          0
# The Ring                      2003-02-07  2003  ...       0          0
# Antitrust                     2001-06-01  2001  ...       1          0
# Drageløberen                  2008-01-25  2008  ...       0          0
# Just Like Heaven              2005-12-09  2005  ...       0          0
# På skudhold                   1994-01-07  1994  ...       1          0
# A Serious Man                 2009-10-09  2009  ...       0          0
# Mother's Day                  2016-05-04  2016  ...       0          0
# The Believer                  2002-03-01  2002  ...       0          0
# Hedwig and the Angry Inch     2002-07-26  2002  ...       0          0
# 22 Jump Street                2014-06-19  2014  ...       1          0
# White House Down              2013-09-19  2013  ...       1          0
# ...                                  ...   ...  ...     ...        ...
# What Dreams May Come          1999-04-16  1999  ...       0          0
# The Pink Panther 2            2009-02-20  2009  ...       1          1
# Cronos                        1993-12-03  1993  ...       0          0
# Det skøre hold                1990-02-16  1990  ...       0          0
# Fish Tank                     2010-09-30  2010  ...       0          0
# Kung Fu Panda 2               2011-06-16  2011  ...       1          1
# Adrift                        2018-06-14  2018  ...       1          1
# Bridget Jones' dagbog         2001-07-27  2001  ...       0          0
# Meet the Blacks               2016-04-01  2016  ...       0          0
# Money Talks                   1998-05-22  1998  ...       1          0
# Quarantine                    2008-12-05  2008  ...       0          0
# Skyfall                       2012-10-26  2012  ...       1          1
# Min mikro-makker              1987-12-26  1987  ...       1          1
# Værelse med udsigt            1987-03-02  1987  ...       0          0
# Jobs                          2013-09-05  2013  ...       0          0
# Secretariat                   2010-10-08  2010  ...       0          0
# Lions for Lambs               2007-11-09  2007  ...       0          0
# Gosford Park                  2002-02-08  2002  ...       0          0
# The Skeleton Key              2005-08-12  2005  ...       0          0
# Frankie & Johnny              1992-01-31  1992  ...       0          0
# Kill the Irishman             2012-05-11  2012  ...       0          0
# Klienten                      1994-09-09  1994  ...       0          0
# The Jacket                    2005-06-10  2005  ...       0          0
# Voldens gade                  1981-08-21  1981  ...       1          0
# Table 19                      2017-06-22  2017  ...       0          0
# Hundehotellet                 2009-01-30  2009  ...       0          0
# Breaking Dawn - del 1                0         0
# Giftig viden                         0         1
# En lang forlovelse                   0         0
# Du almægtige, Evan                   1         0
# Little Miss Sunshine                 0         0
# Det hemmelighedsfulde selskab        1         0
# Lords of Dogtown                     0         0
# Freddy Got Fingered                  0         0
# Lunefulde måne                       0         0
# One Hour Photo                       0         1
# Mars Attacks                         0         0
# Split                                0         1
# Total Recall                         0         0
# Januar har to ansigter               0         1
# Grimsby                              0         0
# Hot Shots!                           0         0
# Eventyret om Despero                 0         0
# The Island of Dr. Moreau             0         1
# Mig og Annie                         0         0
# The Ring                             0         0
# Antitrust                            0         0
# Drageløberen                         0         0
# Just Like Heaven                     1         0
# På skudhold                          0         0
# A Serious Man                        0         0
# Mother's Day                         0         0
# The Believer                         0         0
# Hedwig and the Angry Inch            0         0
# 22 Jump Street                       0         0
# White House Down                     0         1
# ...                                ...       ...
# What Dreams May Come                 1         0
# The Pink Panther 2                   0         0
# Cronos                               0         0
# Det skøre hold                       0         0
# Fish Tank                            0         0
# Kung Fu Panda 2                      0         0
# Adrift                               0         0
# Bridget Jones' dagbog                0         0
# Meet the Blacks                      0         0
# Money Talks                          0         0
# Quarantine                           0         1
# Skyfall                              0         1
# Min mikro-makker                     0         0
# Værelse med udsigt                   0         0
# Jobs                                 0         0
# Secretariat                          0         0
# Lions for Lambs                      0         1
# Gosford Park                         0         0
# The Skeleton Key                     0         0
# Frankie & Johnny                     0         0
# Kill the Irishman                    0         0
# Klienten                             0         0
# The Jacket                           1         0
# Voldens gade                         0         0
# Table 19                             0         0
# Hundehotellet                        0         0
# 300: Rise of an Empire               1         0
# Nu eller aldrig                      0         0
# Smølferne 2                          0         0
# Stand-in for mord                    0         0
#
# [3819 rows x 33 columns]

# %% [markdown]
# # Ratings function (main function)
# ## Will scrape each ranking URL from relevant data.
# ### Title is gathered by selector while the rankings are gathered by HTML converted into list which then is calculated

# %%
################### sub function making a list and from list created variables in main function ###################
def find_ratings(soup, rate):        
    for i in soup.select("#main > section > div > table:nth-child(14)")[0].find_all('div', class_='bigcell'):
        rate.append(i.text)
# find_ratings(BeautifulSoup(requests.get("https://www.imdb.com//title/tt0266543/ratings").text, "html.parser"))        
# rate


def ratings_extractor(url):
    r_r, call_id = connector.get(url, "ROFLMAO")
    soup_ = BeautifulSoup(requests.get(url).text, "html.parser")
    rate = []
    try:
        title = soup_.select("#main > section > div > div.subpage_title_block > div > div.parent > h3 > a")[0].text
        find_ratings(soup_,rate)
        check = [float(i) for i in rate]
        rate_all = [float(i) for i in rate][0]
        rate_young = float(round(np.array(list(np.array([float(i) for i in rate])[[1, 2, 6, 7, 11, 12]])).sum()/6, 2)) 
        rate_old = float(round(np.array((np.array([float(i) for i in rate])[[3,4,8,9,13,14]])).sum()/6, 2))
        rate_male = [float(i) for i in rate][5]
        rate_female = [float(i) for i in rate][10]
    except:
        title = None
        rate_all = None
        rate_young = None
        rate_old = None
        rate_male = None
        rate_female = None
    return {
        'title': title,
        'rate_all': rate_all,
        'rate_young': rate_young,
        'rate_old': rate_old,
        'rate_male': rate_male,
        'rate_female': rate_female
        }
ratings_extractor('https://www.imdb.com//title/tt0218817/ratings') #fordi den bliver None, skal de fjernes efter
# Out:
# {'rate_all': None,
#  'rate_female': None,
#  'rate_male': None,
#  'rate_old': None,
#  'rate_young': None,
#  'title': None}

# %% [markdown]
# # Gathering all titles and their rankings using main function.
# ## Each ranking url has it's own dictionary. Each dictionary is stored as a list

# %%
# rankings for each films are stored in links_r
links_r = [x+'ratings' for x in links]
res_r = []
# for idx, i in enumerate(links_r):
#     print(idx + 1, "of", len(links_r))
#     res_r.append(ratings_extractor(i))
    
    

# links_r[26] #det er link nummer 27 der forvolder problemer

# %% [markdown]
# # Translating the list of dictionaries into a DataFrame
# ## rankings-DataFrame

# %%
# df_r = pd.DataFrame(res_r).dropna() #dropper de film der mangler ratings fra en bestemt gruppe


# df_r.to_pickle('all_ratings.pkl') #husk kun at brug når data skal uploades/gemmes
df_r = pd.read_pickle('all_ratings.pkl').dropna() #husk kun at brug når data skal downloades/hentes
df_r = df_r.set_index(df_r['title'], drop=True)
del df_r['title']
df_r
# Out:
#                                                   rate_all  rate_female  \
# title
# Recep Ivedik                                           4.6          3.5
# Breaking Dawn - del 1                                  4.9          5.8
# Giftig viden                                           7.1          6.9
# En lang forlovelse                                     7.6          7.7
# Du almægtige, Evan                                     5.4          5.6
# Hotel Mumbai                                           7.6          7.9
# Little Miss Sunshine                                   7.8          7.9
# Det hemmelighedsfulde selskab                          5.8          6.2
# Lords of Dogtown                                       7.1          7.3
# Freddy Got Fingered                                    4.6          3.9
# Lunefulde måne                                         7.1          7.3
# Far from the Madding Crowd                             7.1          7.3
# One Hour Photo                                         6.8          6.6
# Hvid                                                   7.7          7.6
# Mars Attacks                                           6.3          6.3
# Split                                                  7.3          7.4
# Total Recall                                           6.3          6.3
# Januar har to ansigter                                 6.2          6.1
# Grimsby                                                6.2          5.9
# Hot Shots!                                             6.8          6.5
# Eventyret om Despero                                   6.1          6.3
# The Island of Dr. Moreau                               4.5          4.6
# Mig og Annie                                           8.0          7.8
# The Ring                                               7.1          7.0
# Hector and the Search for Happiness                    7.0          7.1
# Rejsen til Amerika II: Fievel i det vilde vesten       6.5          6.8
# Drageløberen                                           7.6          7.7
# Just Like Heaven                                       6.7          6.8
# På skudhold                                            5.8          6.0
# A Serious Man                                          7.0          6.9
# ...                                                    ...          ...
# Adrift                                                 6.6          6.9
# Asterix og Obelix i kamp mod Cæsar                     5.9          6.2
# Bridget Jones' dagbog                                  6.7          7.2
# Meet the Blacks                                        4.9          4.0
# Money Talks                                            6.2          6.1
# Quarantine                                             6.0          6.0
# Skyfall                                                7.7          7.7
# Arn - Tempelridderen                                   6.6          6.8
# Chungking Express                                      8.1          8.2
# Min mikro-makker                                       6.8          6.9
# Værelse med udsigt                                     7.3          7.5
# Jobs                                                   5.9          6.0
# Secretariat                                            7.2          7.6
# Wasabi                                                 6.7          6.9
# Lions for Lambs                                        6.2          6.2
#                                                   rate_young
# title
# Recep Ivedik                                            4.83
# Breaking Dawn - del 1                                   5.18
# Giftig viden                                            7.20
# En lang forlovelse                                      8.38
# Du almægtige, Evan                                      5.67
# Hotel Mumbai                                            7.97
# Little Miss Sunshine                                    7.98
# Det hemmelighedsfulde selskab                           5.95
# Lords of Dogtown                                        7.40
# Freddy Got Fingered                                     4.87
# Lunefulde måne                                          7.52
# Far from the Madding Crowd                              7.42
# One Hour Photo                                          7.22
# Hvid                                                    7.62
# Mars Attacks                                            6.03
# Split                                                   7.53
# Total Recall                                            6.38
# Januar har to ansigter                                  5.97
# Grimsby                                                 5.98
# Hot Shots!                                              5.95
# Eventyret om Despero                                    6.20
# The Island of Dr. Moreau                                3.60
# Mig og Annie                                            8.18
# The Ring                                                7.13
# Hector and the Search for Happiness                     7.53
# Rejsen til Amerika II: Fievel i det vilde vesten        6.30
# Drageløberen                                            7.42
# Just Like Heaven                                        6.97
# På skudhold                                             6.88
# A Serious Man                                           7.70
# ...                                                      ...
# Adrift                                                  6.98
# Asterix og Obelix i kamp mod Cæsar                      6.45
# Bridget Jones' dagbog                                   6.95
# Meet the Blacks                                         4.60
# Money Talks                                             7.07
# Quarantine                                              5.85
# Skyfall                                                 8.00
# Arn - Tempelridderen                                    6.52
# Chungking Express                                       8.18
# Min mikro-makker                                        6.77
# Værelse med udsigt                                      7.03
# Jobs                                                    6.30
# Secretariat                                             7.10
# Wasabi                                                  6.85
# Lions for Lambs                                         6.98
# Gosford Park                                            7.15
# The Skeleton Key                                        6.87
# De 39 trin                                              7.45
# Frankie & Johnny                                        7.67
# Legenden om Jordhavet                                   6.55
# Punkt 22                                                6.72
# Klienten                                                7.65
# The Jacket                                              7.25
# Table 19                                                5.95
# Youth                                                   7.60
# Hundehotellet                                           5.55
# 300: Rise of an Empire                                  6.25
# Nu eller aldrig                                         7.55
# Smølferne 2                                             5.22
# Stand-in for mord                                       7.20
#
# [4468 rows x 5 columns]

# %% [markdown]
# # Merging movie-attribute-DataFrame with rankings-DataFrame, using innerjoin on the movie titles

# %%
df_master = pd.merge(df2, df_r, on='title', how='inner')

df_master = df_master.drop("Fetih 1453", axis=0)
df_master['cumulative_world_gross']=round(df_master['cumulative_world_gross']/1000000,3)
df_master['budget']=df_master['budget']/1000000
df_master['profit']=(df_master['cumulative_world_gross']-df_master['budget'])
df_master['return'] = round(df_master['cumulative_world_gross']/df_master['budget'],2)
df_master['gross_usa']=round(df_master['gross_usa']/1000000,2)
df_master

#note that https://www.imdb.com//title/tt1783232/ has a budget of 18 dollars while grossing 35 million dollar.
df_master.loc[df_master['return'].idxmax()]
#It should've been 18 mio according to google.
# Out:
# budget                                                     0.015
# cumulative_world_gross                                   265.118
# date                                             4 December 2009
# genre                                [Horror, Mystery, Thriller]
# gross_usa                                                 107.92
# rating                                                       6.3
# runtime                                                       86
# url                       https://www.imdb.com//title/tt1179904/
# datetime                                     2009-12-04 00:00:00
# year                                                        2009
# month                                                         12
# day                                                            4
# Crime                                                          0
# Sport                                                          0
# Western                                                        0
# Musical                                                        0
# Romance                                                        0
# Comedy                                                         0
# Family                                                         0
# Animation                                                      0
# History                                                        0
# Drama                                                          0
# Biography                                                      0
# Action                                                         0
# Adventure                                                      0
# Mystery                                                        1
# Film-Noir                                                      0
# Sci-Fi                                                         0
# War                                                            0
# Horror                                                         1
# Music                                                          0
# Fantasy                                                        0
# Thriller                                                       1
# rate_all                                                     6.3
# rate_female                                                  6.1
# rate_male                                                    6.3
# rate_old                                                     6.2
# rate_young                                                  6.13
# profit                                                   265.103
# return                                                   17674.5
# Name: Paranormal Activity, dtype: object

# %% [markdown]
# # Deskriptiv statistik

# %%
def category_summary(df, category, categories):
    categories = list(categories)
    stats = ["rate_all", "rate_female", "rate_male", "rate_old", "rate_young"]
    df_ = df[stats + categories]
    df_ = df_[df_[category] == 1]
    return df_[stats].mean() 




print(category_summary(df_master, "Fantasy", ["Fantasy"])) #examples
print(category_summary(df_master, "Horror", ["Horror"])) #exmaples

rated = []
for idx, i in enumerate(categories):
    print(idx+1, 'of', len(categories))
    rated.append(category_summary(df_master, i, [i]))
    
# rated 
df_rated=pd.DataFrame(rated, index=categories)
df_rated

#Check at categories er defineret ud fra hvilke genre der rent faktisk er i datasættet
# Out:
# rate_all       6.463314
# rate_female    6.653846
# rate_male      6.397337
# rate_old       6.469467
# rate_young     6.621006
# dtype: float64
# rate_all       6.131702
# rate_female    6.180653
# rate_male      6.106527
# rate_old       6.111329
# rate_young     6.212774
# dtype: float64
# 1 of 21
# 2 of 21
# 3 of 21
# 4 of 21
# 5 of 21
# 6 of 21
# 7 of 21
# 8 of 21
# 9 of 21
# 10 of 21
# 11 of 21
# 12 of 21
# 13 of 21
# 14 of 21
# 15 of 21
# 16 of 21
# 17 of 21
# 18 of 21
# 19 of 21
# 20 of 21
# 21 of 21
#            rate_all  rate_female  rate_male  rate_old  rate_young
# Crime      6.688169     6.728849   6.669044  6.617812    6.967909
# Sport      6.768421     6.786842   6.735526  6.672632    6.986842
# Western    7.469565     7.373913   7.465217  7.411739    7.628261
# Musical    6.927778     7.191667   6.788889  6.821389    7.148889
# Romance    6.626200     6.752400   6.533800  6.570260    6.865940
# Comedy     6.434578     6.528896   6.375649  6.371088    6.648969
# Family     6.362397     6.662810   6.229752  6.374876    6.516240
# Animation  6.930594     7.113242   6.868950  6.896712    6.974201
# History    7.192000     7.335000   7.145000  7.191400    7.351000
# Drama      6.980038     7.056210   6.931369  6.925456    7.188853
# Biography  7.237662     7.340260   7.194372  7.205801    7.450519
# Action     6.420234     6.523962   6.393078  6.395570    6.609872
# Adventure  6.549937     6.704930   6.505689  6.541340    6.678938
# Mystery    6.553977     6.602841   6.536364  6.515852    6.685795
# Film-Noir  8.200000     8.100000   8.200000  8.185000    8.375000
# Sci-Fi     6.510089     6.563501   6.491691  6.482819    6.564303
# War        7.475472     7.513208   7.450943  7.425660    7.656792
# Horror     6.131702     6.180653   6.106527  6.111329    6.212774
# Music      6.825882     6.945882   6.729412  6.707412    7.160118
# Fantasy    6.463314     6.653846   6.397337  6.469467    6.621006
# Thriller   6.583034     6.613377   6.567537  6.543589    6.776852

# %%
def genre_stats(df, category, categories):
    categories = list(categories)
    stats = ["cumulative_world_gross", "budget", 'rating']
    df_ = df[stats + categories]
    df_ = df_[df_[category] == 1]
    return df_[stats].mean() 
#husk at inkluder antallet af observationer pr. genre

print(genre_stats(df_master, "Musical", ["Musical"]))


money = []
for idx, i in enumerate(categories):
    money.append(genre_stats(df_master, i, [i]))
    
# rated 
df_money=pd.DataFrame(money, index=categories)
df_money['genres']=categories
df_money['cumulative_world_gross']=round(df_money['cumulative_world_gross'],2)
df_money['budget']=round(df_money['budget'],2)
df_money['profit']=(df_money['cumulative_world_gross']-df_money['budget'])
df_money['return']=round(df_money['cumulative_world_gross']/df_money['budget'],2)
df_money['rating']=round(df_money['rating'],2)

df_money
# Out:
# cumulative_world_gross    126.030667
# budget                     31.506133
# rating                      6.927778
# dtype: float64
#            cumulative_world_gross  budget  rating     genres  profit  return
# Crime                       82.19   33.54    6.68      Crime   48.65    2.45
# Sport                       81.02   34.76    6.70      Sport   46.26    2.33
# Western                     74.01   23.84    7.47    Western   50.17    3.10
# Musical                    126.03   31.51    6.93    Musical   94.52    4.00
# Romance                     94.02   28.56    6.62    Romance   65.46    3.29
# Comedy                     127.12   38.50    6.43     Comedy   88.62    3.30
# Family                     205.90   58.99    6.37     Family  146.91    3.49
# Animation                  304.81   79.07    6.94  Animation  225.74    3.85
# History                     92.27   40.13    7.22    History   52.14    2.30
# Drama                       89.05   31.28    6.97      Drama   57.77    2.85
# Biography                   74.85   29.66    7.25  Biography   45.19    2.52
# Action                     193.09   67.46    6.40     Action  125.63    2.86
# Adventure                  263.81   78.81    6.54  Adventure  185.00    3.35
# Mystery                     92.11   28.24    6.53    Mystery   63.87    3.26
# Film-Noir                    1.29    1.29    8.20  Film-Noir    0.00    1.00
# Sci-Fi                     195.23   63.35    6.50     Sci-Fi  131.88    3.08
# War                         75.19   27.56    7.48        War   47.63    2.73
# Horror                      70.72   20.22    6.10     Horror   50.50    3.50
# Music                       81.38   21.38    6.86      Music   60.00    3.81
# Fantasy                    188.86   58.71    6.44    Fantasy  130.15    3.22
# Thriller                   112.67   35.71    6.59   Thriller   76.96    3.16

# %%
df_master.describe()
df_master['return'].describe()
# Out:
# count     3377.000000
# mean        12.696213
# std        320.430988
# min          0.000000
# 25%          1.310000
# 50%          2.610000
# 75%          4.900000
# max      17674.530000
# Name: return, dtype: float64

# %%
import matplotlib.style as style
style.use('seaborn-poster')

barplot1 = df_money.sort_values('cumulative_world_gross', ascending=False).plot.bar(x='genres', y='cumulative_world_gross', title='Mean gross revenue by genre', legend=False, color = '#007ACC')
# barplot[0].set_color('red')
barplot1.set_ylabel('Mean total gross (million $)', weight='bold')
barplot1.set_xlabel('Genre', weight='bold')





df_money = df_money.sort_values(by='return')
my_range = list(range(1,len(df_money.index)+1))
fig, ax = plt.subplots(figsize=(15,8))
plt.hlines(y=my_range, xmin=0, xmax=df_money['return'], color='#007acc', alpha=0.2, linewidth=5)
plt.plot(df_money['return'], my_range, "o", markersize=5, color='#007ACC', alpha=0.6)
ax.set_xlabel('Return', fontsize=20, fontweight='black', color = '#333F4B')
ax.set_ylabel('')
ax.tick_params(axis='both', which='major', labelsize=12)
plt.yticks(my_range, df_money.index)
fig.text(0.05, 0.87, 'Genre', fontsize=20, fontweight='black', color = '#333F4B')
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)
ax.spines['bottom'].set_position(('axes', -0.04))
ax.spines['left'].set_position(('axes', 0.015))


barplot2 = df_money.sort_values('budget', ascending=False).plot.bar(x='genres', y='budget', title='Mean budget by genre', legend=False, color = '#007ACC')
# barplot[0].set_color('red')
barplot2.set_ylabel('Mean budget (million $)', weight='bold')
barplot2.set_xlabel('Genre', weight='bold')

df_money.sort_values('return', ascending=False).plot.bar(x='genres', y='return')



scatter1 = df_master.plot.scatter(x='budget', y='cumulative_world_gross', title='Budget and total gross correlation', legend=False, color = '#007ACC')
# barplot[0].set_color('red')
scatter1.set_ylabel('Mean total gross (million $)', weight='bold')
scatter1.set_xlabel('budget (million $)', weight='bold')

scatter2 = df_master.plot.scatter(x='rating', y='return', title='Rating and return', legend=False, color = '#007ACC')
# barplot[0].set_color('red')
scatter2.set_ylabel('Return (gross/budget)', weight='bold')
scatter2.set_ylim([0,12])
scatter2.set_xlabel('Rating', weight='bold')
# Out:
# Text(0.5, 0, 'Rating')

# %%
ax = sns.boxplot(y='return', data=df_master).set_title('Boxplots of return (Total gross / budget)')
ax.set_ylabel('Return')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-26c03e5682eb> in <module>()
#       1 ax = sns.boxplot(y='return', data=df_master).set_title('Boxplots of return (Total gross / budget)')
# ----> 2 ax.set_ylabel('Return')
#
# AttributeError: 'Text' object has no attribute 'set_ylabel'

# %% [markdown]
# ## Machine Learning
# Importing the relevant packages

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import mean_squared_error as mse
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %% [markdown]
# ### Defining the features and target from our dataframe

# %%
X = df_master[['budget', 'rating', 'runtime', *list(categories)]]
X_r = df_master[['rating', 'runtime', *list(categories)]]
y = df_master['cumulative_world_gross']
y_r = df_master['cumulative_world_gross']/df_master['budget']

from sklearn.model_selection import train_test_split

# %%
def rmse(y_pred, y_true):
    return np.sqrt(mse(y_pred, y_true))

output=[]

for random_state in range(10):
    X_dev, X_test, y_dev, y_test = train_test_split(X, y, test_size=1/3, random_state=1)
    X_train, X_val, y_train, y_val = train_test_split(X_dev, y_dev, test_size=1/2, random_state=1)
    
    reg = LinearRegression().fit(X_train, y_train)
    reg.predict(X_test)
    
    output.append([rmse(reg.predict(X_val), y_val),
                  rmse(reg.predict(X_test), y_test)])
    
print(pd.DataFrame(output, columns=['test', 'validation']))

print(pd.DataFrame(output, columns=['test', 'validation']).describe())
# Out:
#          test  validation
# 0  133.403524  119.394456
# 1  133.403524  119.394456
# 2  133.403524  119.394456
# 3  133.403524  119.394456
# 4  133.403524  119.394456
# 5  133.403524  119.394456
# 6  133.403524  119.394456
# 7  133.403524  119.394456
# 8  133.403524  119.394456
# 9  133.403524  119.394456
#                test  validation
# count  1.000000e+01   10.000000
# mean   1.334035e+02  119.394456
# std    2.995911e-14    0.000000
# min    1.334035e+02  119.394456
# 25%    1.334035e+02  119.394456
# 50%    1.334035e+02  119.394456
# 75%    1.334035e+02  119.394456
# max    1.334035e+02  119.394456

# %% [markdown]
# ### Finding the optimal lambda, by OLS

# %%
from sklearn.model_selection import KFold
kfolds = KFold(n_splits=10) #Splits the data 10 times into evenly sized bins. 
folds = list()

lambdas = np.logspace(-4,4,10)
# outer loop: lambdas
rmseCV = []
perform = []

for lambda_ in lambdas:    
    # inner loop: folds. For each of the folds (Splits),
    rmseCV_ = []    
    for train_idx, val_idx in kfolds.split(X_dev, y_dev):        
        # train model and compute MSE on test fold
        pipe_OLSCV = make_pipeline(ColumnTransformer(
                                    [("Continous", make_pipeline(
                                         StandardScaler(),
                                         PolynomialFeatures()
                                     ), [0,2]), 
                                      ("", 'passthrough', [i for i in range(3, X.shape[1])])
                                     ]),
                                    LinearRegression())
        X_train, y_train, = X_dev.iloc[train_idx], y_dev[train_idx] #Selection where we throw in the indices and take out the data
        X_val, y_val = X_dev.iloc[val_idx], y_dev[val_idx] 
        pipe_OLSCV.fit(X_train, y_train)  #Fit the model on the training data, estimation
        rmseCV_.append(rmse(pipe_OLSCV.predict(X_val), y_val))   #Apply the model to the validation data and store it in an empty list
    #y_val_pred = pipe_lassoCV.predict(X_val)
    #y_train_pred = pipe_lassoCV.predict(X_train)
    #y_test_pred = pipe_lassoCV.predict(X_test)
    #perform.append(mse(y_pred, y_val))
    # store result    
    rmseCV.append(sum(rmseCV_)/len(rmseCV_)) 
    
# convert to DataFrame
lambdaCV = pd.DataFrame(rmseCV, index=lambdas)

lambdaCV

optimal_lambda = lambdaCV.mean(axis=1).nsmallest(1)
optimal_lambda
# Out:
# 0.0001    124.257157
# dtype: float64

# %% [markdown]
# ### Predicting of our target using the three different datasets: Train, validation and test

# %%
y_val_pred = pipe_lassoCV.predict(X_val)
y_train_pred = pipe_lassoCV.predict(X_train)
y_test_pred = pipe_lassoCV.predict(X_test)
    #perform.append(mse(y_pred, y_val))

# %% [markdown]
# ## Machine learning, OLS with Lasso
#
# From computing the descriptive statistics of RMSE for the train data on  the test and validation data we can conclude we can split the train data and use this to fit the model. This is because the descriptive statistics are quite similar and we therefore presume our model i generalizing enough. (Balanced).

# %%
from sklearn.model_selection import KFold
kfolds = KFold(n_splits=10) #Splits the data 10 times into evenly sized bins. 
folds = list()

lambdas = np.logspace(-4,4,10)
# outer loop: lambdas
rmseCV = []
perform = []

for lambda_ in lambdas:    
    # inner loop: folds. For each of the folds (Splits),
    rmseCV_ = []    
    for train_idx, val_idx in kfolds.split(X_dev, y_dev):        
        # train model and compute MSE on test fold
        pipe_lassoCV = make_pipeline(ColumnTransformer(
                                    [("Continous", make_pipeline(
                                         StandardScaler(),
                                         PolynomialFeatures()
                                     ), [0,2]), 
                                      ("", 'passthrough', [i for i in range(3, X.shape[1])])
                                     ]),
                                    Lasso(alpha=lambda_, random_state=1))
        X_train, y_train, = X_dev.iloc[train_idx], y_dev[train_idx] #Selection where we throw in the indices and take out the data
        X_val, y_val = X_dev.iloc[val_idx], y_dev[val_idx] 
        pipe_lassoCV.fit(X_train, y_train)  #Fit the model on the training data, estimation
        rmseCV_.append(rmse(pipe_lassoCV.predict(X_val), y_val))   #Apply the model to the validation data and store it in an empty list
    #y_val_pred = pipe_lassoCV.predict(X_val)
    #y_train_pred = pipe_lassoCV.predict(X_train)
    #y_test_pred = pipe_lassoCV.predict(X_test)
    #perform.append(mse(y_pred, y_val))
    # store result    
    rmseCV.append(sum(rmseCV_)/len(rmseCV_)) 
    
# convert to DataFrame
lambdaCV = pd.DataFrame(rmseCV, index=lambdas)

lambdaCV

optimal_lambda = lambdaCV.mean(axis=1).nsmallest(1)
optimal_lambda
# Out:
# 0.359381    124.026584
# dtype: float64

# %%
Lasso_coefficients = reg.coef_
Lasso_intercept = reg.intercept_


print(Lasso_coefficients)
print(Lasso_intercept)

#Zip eller plot dem sammen
# Out:
# [ 2.59476356e+00  3.08536688e+01  3.99934716e-01 -1.66712335e+01
#  -3.92382828e+01 -1.72847476e+01 -2.19159782e+01 -9.96409385e-01
#  -6.21597215e+00  3.86171081e+01  5.22930777e+01 -3.91256375e+01
#  -3.87376265e+01 -2.69631543e+01 -2.40943009e+01  1.45175341e+01
#  -9.00993430e+00  7.10542736e-15  2.09613914e+00 -4.37530897e+01
#   5.60453021e+00 -2.12664580e+01 -2.24148901e+01 -4.98891415e+00]
# -199.73303104384303

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, test_scores = \
    learning_curve(estimator=pipe_lassoCV,
                   X=X_train,
                   y=y_train,
                   train_sizes=np.arange(0.2, 1, .01),
                   scoring='neg_mean_squared_error',                 
                   cv=3)
    
mse_ = pd.DataFrame({'Train':-train_scores.mean(axis=1),
                     'Test':-test_scores.mean(axis=1)})\
        .set_index(pd.Index(train_sizes,name='sample size'))    
print(mse_.head(3))
# Out:
#                     Train          Test
# sample size
# 270          37708.559469  34740.029663
# 283          36424.489822  34739.269085
# 297          37738.346585  34724.353562

# %%
f_learn, ax = plt.subplots(figsize=(10,4))
ax.fill_between(train_sizes,
                -test_scores.mean(1) + test_scores.std(1)*1.96,
                -test_scores.mean(1) - test_scores.std(1)*1.96, 
                alpha=0.25, label ='Test', color='blue')

ax.fill_between(train_sizes,
                -train_scores.mean(1) + train_scores.std(1)*1.96,
                -train_scores.mean(1) - train_scores.std(1)*1.96, 
                alpha=0.25, label='Train', color='orange')
ax.set_ylabel('Mean squared error')
ax.set_yscale('log')
ax.legend()

# %%
from sklearn.model_selection import validation_curve

train_scores, test_scores = \
    validation_curve(estimator=pipe_lassoCV,
                     X=X_dev,
                     y=y_dev,
                     param_name='lasso__alpha',
                     param_range=lambdas,
                     scoring='neg_mean_squared_error',                 
                     cv=3)

mse_score = pd.DataFrame({'Train':-train_scores.mean(axis=1),
                          'Validation':-test_scores.mean(axis=1),
                          'lambda':lambdas})\
              .set_index('lambda')   
print(mse_score.Validation.nsmallest(1))
# Out:
# lambda
# 0.359381    15723.635899
# Name: Validation, dtype: float64

# %%
mse_score.plot(logx=True, logy=True)

#overfitter fordi den er bedre på train end validation

# %% [markdown]
# ## Prediction of the cumulative gross in relation to the budget

# %%
def rmse(y_pred, y_true):
    return np.sqrt(mse(y_pred, y_true))

output=[]

for random_state in range(10):
    X_r_dev, X_r_test, y_r_dev, y_r_test = train_test_split(X_r, y_r, test_size=1/3, random_state=1)
    X_r_train, X_r_val, y_r_train, y_r_val = train_test_split(X_r_dev, y_r_dev, test_size=1/2, random_state=1)
    
    reg = LinearRegression().fit(X_r_train, y_r_train)
    reg.predict(X_r_test)
    
    output.append([rmse(reg.predict(X_r_val), y_r_val),
                  rmse(reg.predict(X_r_test), y_r_test)])

print(pd.DataFrame(output, columns=['test', 'validation']))

print(pd.DataFrame(output, columns=['test', 'validation']).describe())
# Out:
#          test  validation
# 0  123.597891  540.740645
# 1  123.597891  540.740645
# 2  123.597891  540.740645
# 3  123.597891  540.740645
# 4  123.597891  540.740645
# 5  123.597891  540.740645
# 6  123.597891  540.740645
# 7  123.597891  540.740645
# 8  123.597891  540.740645
# 9  123.597891  540.740645
#                test  validation
# count  1.000000e+01   10.000000
# mean   1.235979e+02  540.740645
# std    1.497956e-14    0.000000
# min    1.235979e+02  540.740645
# 25%    1.235979e+02  540.740645
# 50%    1.235979e+02  540.740645
# 75%    1.235979e+02  540.740645
# max    1.235979e+02  540.740645

# %%
from sklearn.model_selection import KFold
kfolds = KFold(n_splits=10) #Splits the data 10 times into evenly sized bins. 
folds = list()

lambdas = np.logspace(-4,4,10)
# outer loop: lambdas
rmseCV = []
perform = []

for lambda_ in lambdas:    
    # inner loop: folds. For each of the folds (Splits),
    rmseCV_ = []    
    for train_idx, val_idx in kfolds.split(X_r_dev, y_r_dev):        
        # train model and compute MSE on test fold
        pipe_lassoCV = make_pipeline(ColumnTransformer(
                                    [("Continous", make_pipeline(
                                         StandardScaler(),
                                         PolynomialFeatures()
                                     ), [0,1]), 
                                      ("", 'passthrough', [i for i in range(2, X_r.shape[1])])
                                     ]),
                                    Lasso(alpha=lambda_, random_state=1))
        X_r_train, y_r_train, = X_r_dev.iloc[train_idx], y_r_dev[train_idx] #Selection where we throw in the indices and take out the data
        X_r_val, y_r_val = X_r_dev.iloc[val_idx], y_r_dev[val_idx] 
        pipe_lassoCV.fit(X_r_train, y_r_train)  #Fit the model on the training data, estimation
        rmseCV_.append(rmse(pipe_lassoCV.predict(X_r_val), y_r_val))   #Apply the model to the validation data and store it in an empty list
    #y_val_pred = pipe_lassoCV.predict(X_val)
    #y_train_pred = pipe_lassoCV.predict(X_train)
    #y_test_pred = pipe_lassoCV.predict(X_test)
    #perform.append(mse(y_pred, y_val))
    # store result    
    rmseCV.append(sum(rmseCV_)/len(rmseCV_)) 
    
# convert to DataFrame
lambdaCV = pd.DataFrame(rmseCV, index=lambdas)

lambdaCV

optimal_lambda = lambdaCV.mean(axis=1).nsmallest(1)
optimal_lambda
# Out:
# 2.782559    36.921914
# dtype: float64

# %% [markdown]
# # Code for plots

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import seaborn as sns

plt.style.use('ggplot')
# %matplotlib inline

SMALL_SIZE = 16
MEDIUM_SIZE = 18
BIGGER_SIZE = 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
