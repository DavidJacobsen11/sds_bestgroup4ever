# %%
### We create our log file

# %%
## %matplotlib inline
import matplotlib.pyplot as plt
import requests, re, time
from bs4 import BeautifulSoup
import scraping_class
import pprint
import pandas as pd
import numpy as np
logfile = 'the_log.csv'## name your log file.
connector = scraping_class.Connector(logfile)
session = requests.session()
session.headers['wmd776@alumni.ku.dk'] = 'wmd776@alumni.ku.dk' 
session.headers['Amalie Tokkesdal'] = 'Amalie Tokkesdal'
session.headers
# Out:
# {'User-Agent': 'python-requests/2.21.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'wmd776@alumni.ku.dk': 'wmd776@alumni.ku.dk', 'Amalie Tokkesdal': 'Amalie Tokkesdal'}

# %% [markdown]
# ### Parsing HTML with BeautifulSoup
#
# When parsing, we took advantage of the pyhton library BeautifulSoup.
#
# "BeautifulSoup makes the html tree navigable.
# It allows you to:
#     * Search for elements by tag name and/or by attribute.
#     * Iterate through them, go up, sideways or down the tree.
#     * Furthermore it helps you with standard tasks such as extracting raw text from html,
#     which would be a very tedious task if you had to hardcode it using `.split` commands and using your own regular expressions will be unstable."

# %%
#IMDb advanced search -> feature films -> num votes decending

#url=[]
#for n in range (1,5251,250):
#    url.append('https://www.imdb.com/search/title/?title_type=feature&num_votes=20000,&sort=moviemeter,desc&count=250&start=' + str(n) + '&ref_=adv_nxt')
   


#links = []
#import time
#for x in url:
#    time.sleep(0.5)
#    response = requests.get(x)
#    if response.ok:
#        html = response.text
#    else:
#        print('error')
#    BeautifulSoup(html,'html.parser')
#    link_location = html.split('href="')[1:]
    


#    for link_loc in link_location:
#        link = link_loc.split('"')[0].strip('vote?v=X;k=').strip('?ref_=adv_li_tt')
        #link = link_loc.split('"')[0].strip('tile_type')      -> don't know why this wont work
#        if '/title/' in link:
#            links.append(link) 
#links = ['https://www.imdb.com/'+link for link in links if not 'title_type' in link and not 'ref' in link and not 'plotsummary' in link] # add the domain to each link

#links = set(links)

# %%
links = set(links)

# %% [markdown]
# number_of_movies = 5251
#
#
# url=["https://www.imdb.com/search/title/?title_type=feature&num_votes=20000,&sort=moviemeter,desc&count=250&start={pagenum}&ref_=adv_nxt".format(pagenum = str(pagenum)) for pagenum in range(1,2251, 250)]
#
# from time import sleep
#
# for links in url:
#     time.sleep(0.5)
#     response = requests.get(links)
#     if response.ok:
#         html = response.text
#     else:
#         print('error')
#
# soup = BeautifulSoup(html,'html.parser')
#
# link_location = html.split('href="')[1:]
#
# links = set()

# %% [markdown]
# number_of_movies = 5251
#
#
# url="https://www.imdb.com/chart/top"
# from time import sleep
#
# for links in url:
#     time.sleep(0.5)
#     response = requests.get(url)
#     if response.ok:
#         html = response.text
#     else:
#         print('error')
#
# soup = BeautifulSoup(html,'html.parser')
#
# link_location = html.split('href="')[1:]
#
# links = set()

# %% [markdown]
# for link_loc in link_location:
#     link = link_loc.split('"')[0]
#     if '/title/' in link:
#         links.add(link)
# links = ['https://www.imdb.com/'+link for link in links if not 'ref' in link]# this adds the domain to each link

# %%
def find_budget(soup):
    for i in soup.find(id="titleDetails").find_all("div", class_="txt-block"):
        if i.find().text == "Budget:":
            return float(i.text.strip().split("\n")[0].split("$")[1].replace(",", ""))
        
def find_gross(soup):
    for i in soup.find(id="titleDetails").find_all("div", class_="txt-block"):
        if i.find().text == "Cumulative Worldwide Gross:":
            return float(i.text.strip().split("\n")[0].split("$")[1].replace(",", ""))
        
def find_grossUSA(soup):
    for i in soup.find(id="titleDetails").find_all("div", class_="txt-block"):
        if i.find().text == "Gross USA:":
            return float(i.text.strip().split("\n")[0].split("$")[1].replace(",", ""))

def find_rating(soup):
    for i in soup.find(id="title-overview-widget").find_all("div", class_="ratingValue"):
        return float(i.text.strip().split("/")[0])
        
def find_runtime(soup):
    for i in soup.find(id="titleDetails").find_all("div", class_="txt-block"):
        if i.find().text == "Runtime:":
            return float(i.text.strip().split("\n")[1].split("min")[0].strip())
def find_date(soup):
    for i in soup.find(id="titleDetails").find_all("div", class_="txt-block"):
        if i.find().text == "Release Date:":
            return i.text.strip().split(":")[1].split("(")[0].strip()
        
def find_genre(soup):
    for i in soup.find(id="title-overview-widget").find_all("div", class_="subtext"):
        if str(i.text.strip().split("|")[2].replace('\n','').replace(' ','').split(","))[-3]==(')'):
            return i.text.strip().split("|")[1].replace('\n','').replace(' ','').split(",")
        else:
            return i.text.strip().split("|")[2].replace('\n','').replace(' ','').split(",")

# %% [markdown]
# ### Parsing and cleaning the data
#
# Here we use our earlier defined functions to make a dictionary of all the data we need from the description page of each movie, ie. title, budget, the cumulative worldwide gross, the rating, the runtime, date and genre.

# %%
def page_extractor(url):
    r, call_id = connector.get(url, "LOL")
    try:
        soup = BeautifulSoup(r.text, "html.parser")
        title = soup.select("#title-overview-widget > div.vital > div.title_block > div > div.titleBar > div.title_wrapper > h1")[0].text.split("\xa0")[0]
        budget = find_budget(soup)
        cumulative_worldwide_gross=find_gross(soup)
        gross_usa=find_grossUSA(soup)
        rating = find_rating(soup)
        runtime = find_runtime(soup)
        date= find_date(soup)
        genre = find_genre(soup)
    except:
        soup = None
        title = None
        budget = None
        cumulative_worldwide_gross= None
        gross_usa = None
        rating=None
        runtime = None
        date = None
        genre = None
    return {
        "title": title,
        #"year": year,
        "budget": budget,
        "url": url,
        "cumulative_world_gross": cumulative_worldwide_gross,
        "gross_usa": gross_usa,
        "rating": rating,
        "runtime": runtime,
        "date": date,
        "genre": genre
    }

# %% [markdown]
# ### Create a list and append information from every movie on the list.
# Remark: We have only chosen top 250 so far, as to not make the coding too slow in progress. If you wish to see the whole list, or a minor part of it, simply change the brackets after 'links'.

# %%
#res = []
#for idx, i in enumerate(links):
#    print(idx + 1, "of", len(links))
#    res.append(page_extractor(i))
# Out:
# 1 of 5272
# 2 of 5272
# 3 of 5272
# 4 of 5272
# 5 of 5272
# 6 of 5272
# 7 of 5272
# 8 of 5272
# 9 of 5272
# 10 of 5272
# 11 of 5272
# 12 of 5272
# 13 of 5272
# 14 of 5272
# 15 of 5272
# 16 of 5272
# 17 of 5272
# 18 of 5272
# 19 of 5272
# 20 of 5272
# 21 of 5272
# 22 of 5272
# 23 of 5272
# 24 of 5272
# 25 of 5272
# 26 of 5272
# 27 of 5272
# 28 of 5272
# 29 of 5272
# 30 of 5272
# 31 of 5272
# 32 of 5272
# 33 of 5272
# 34 of 5272
# 35 of 5272
# 36 of 5272
# 37 of 5272
# 38 of 5272
# 39 of 5272
# 40 of 5272
# 41 of 5272
# 42 of 5272
# 43 of 5272
# 44 of 5272
# 45 of 5272
# 46 of 5272
# 47 of 5272
# 48 of 5272
# 49 of 5272
# 50 of 5272
# 51 of 5272
# 52 of 5272
# 53 of 5272
# 54 of 5272
# 55 of 5272
# 56 of 5272
# 57 of 5272
# 5203 of 5272
# 5204 of 5272
# 5205 of 5272
# 5206 of 5272
# 5207 of 5272
# 5208 of 5272
# 5209 of 5272
# 5210 of 5272
# 5211 of 5272
# 5212 of 5272
# 5213 of 5272
# 5214 of 5272
# 5215 of 5272
# 5216 of 5272
# 5217 of 5272
# 5218 of 5272
# 5219 of 5272
# 5220 of 5272
# 5221 of 5272
# 5222 of 5272
# 5223 of 5272
# 5224 of 5272
# 5225 of 5272
# 5226 of 5272
# 5227 of 5272
# 5228 of 5272
# 5229 of 5272
# 5230 of 5272
# 5231 of 5272
# 5232 of 5272
# 5233 of 5272
# 5234 of 5272
# 5235 of 5272
# 5236 of 5272
# 5237 of 5272
# 5238 of 5272
# 5239 of 5272
# 5240 of 5272
# 5241 of 5272
# 5242 of 5272
# 5243 of 5272
# 5244 of 5272
# 5245 of 5272
# 5246 of 5272
# 5247 of 5272
# 5248 of 5272
# 5249 of 5272
# 5250 of 5272
# 5251 of 5272
# 5252 of 5272
# 5253 of 5272
# 5254 of 5272
# 5255 of 5272
# 5256 of 5272
# 5257 of 5272
# 5258 of 5272
# 5259 of 5272
# 5260 of 5272
# 5261 of 5272
# 5262 of 5272
# 5263 of 5272
# 5264 of 5272
# 5265 of 5272
# 5266 of 5272
# 5267 of 5272
# 5268 of 5272
# 5269 of 5272
# 5270 of 5272
# 5271 of 5272
# 5272 of 5272

# %%
res
# Out:
# [{'budget': None,
#   'cumulative_world_gross': 88031955.0,
#   'date': '20 December 2013',
#   'genre': ['Action', 'Thriller'],
#   'gross_usa': 8031955.0,
#   'rating': 5.4,
#   'runtime': 172.0,
#   'title': 'Dhoom:3',
#   'url': 'https://www.imdb.com//title/tt1833673/'},
#  {'budget': 110000000.0,
#   'cumulative_world_gross': 331114051.0,
#   'date': '6 March 2014',
#   'genre': ['Action', 'Fantasy'],
#   'gross_usa': 106580051.0,
#   'rating': 6.2,
#   'runtime': 102.0,
#   'title': '300: Rise of an Empire',
#   'url': 'https://www.imdb.com//title/tt1253863/'},
#  {'budget': 55000000.0,
#   'cumulative_world_gross': 214015089.0,
#   'date': '10 February 1995',
#   'genre': ['Drama', 'Thriller'],
#   'gross_usa': 83015089.0,
#   'rating': 6.1,
#   'runtime': 128.0,
#   'title': 'Afsløring',
#   'url': 'https://www.imdb.com//title/tt0109635/'},
#  {'budget': None,
#   'cumulative_world_gross': 343132.0,
#   'date': '27 July 2001',
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'gross_usa': None,
#   'rating': 8.0,
#   'runtime': 137.0,
#   'title': 'Yeopgijeogin geunyeo',
#   'url': 'https://www.imdb.com//title/tt0293715/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': '27 October 1988',
#   'genre': ['Mystery', 'Thriller'],
#   'gross_usa': None,
#   'rating': 7.8,
#   'runtime': 107.0,
#   'title': 'Spoorloos',
#   'url': 'https://www.imdb.com//title/tt0096163/'},
#  {'budget': 806947.0,
#   'cumulative_world_gross': 32000000.0,
#   'date': '1 May 1961',
#   'genre': ['Horror', 'Mystery', 'Thriller'],
#   'gross_usa': 32000000.0,
#   'rating': 8.5,
#   'runtime': 109.0,
#   'title': 'Psycho',
#   'url': 'https://www.imdb.com//title/tt0054215/'},
#  {'budget': 85000000.0,
#   'cumulative_world_gross': 288885818.0,
#   'date': '10 April 2014',
#   'genre': ['Action', 'Adventure', 'Mystery'],
#   'gross_usa': 150947895.0,
#   'rating': 6.7,
#   'runtime': 139.0,
#   'title': 'Divergent',
#   'url': 'https://www.imdb.com//title/tt1840309/'},
#  {'budget': None,
#   'cumulative_world_gross': 20190985.0,
#   'date': '6 June 2019',
#   'genre': ['Drama', 'History', 'Thriller'],
#   'gross_usa': 9651611.0,
#   'rating': 7.6,
#   'runtime': 123.0,
#   'title': 'Hotel Mumbai',
#   'url': 'https://www.imdb.com//title/tt5461944/'},
#  {'budget': 110000000.0,
#   'cumulative_world_gross': 407711549.0,
#   'date': '2 May 2003',
#   'genre': ['Action', 'Sci-Fi', 'Thriller'],
#   'gross_usa': 214949694.0,
#   'rating': 7.4,
#   'runtime': 134.0,
#   'title': 'X-Men 2',
#   'url': 'https://www.imdb.com//title/tt0290334/'},
#  {'budget': 11000000.0,
#   'cumulative_world_gross': 34872033.0,
#   'date': '13 September 1991',
#   'genre': ['Fantasy', 'Horror'],
#   'gross_usa': 34872033.0,
#   'rating': 4.9,
#   'runtime': 89.0,
#   'title': "Freddy's Dead: The Final Nightmare",
#   'url': 'https://www.imdb.com//title/tt0101917/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': None,
#   'genre': None,
#   'gross_usa': None,
#   'rating': None,
#   'runtime': None,
#   'title': None,
#   'url': 'https://www.imdb.com//title/tt0377713/'},
#  {'budget': 3700000.0,
#   'cumulative_world_gross': 31800000.0,
#   'date': '13 September 1976',
#   'genre': ['Western'],
#   'gross_usa': 31800000.0,
#   'rating': 7.9,
#   'runtime': 135.0,
#   'title': 'Øje for øje',
#   'url': 'https://www.imdb.com//title/tt0075029/'},
#  {'budget': 3300000.0,
#   'cumulative_world_gross': 20618717.0,
#   'date': '30 November 1984',
#   'genre': ['Comedy', 'Family'],
#   'gross_usa': 20605209.0,
#   'rating': 8.0,
#   'runtime': 94.0,
#   'title': 'Christmas Story',
#   'url': 'https://www.imdb.com//title/tt0085334/'},
#  {'budget': None,
#   'cumulative_world_gross': 21612733.0,
#   'date': '24 February 2012',
#   'genre': ['Comedy', 'Romance'],
#   'gross_usa': 17450535.0,
#   'rating': 5.6,
#   'runtime': 98.0,
#   'title': 'Wanderlust',
#   'url': 'https://www.imdb.com//title/tt1655460/'},
#  {'budget': 670000.0,
#   'cumulative_world_gross': 651.0,
#   'date': '1 November 1933',
#   'genre': ['Adventure', 'Horror', 'Sci-Fi'],
#   'gross_usa': None,
#   'rating': 7.9,
#   'runtime': 100.0,
#   'title': 'King Kong',
#   'url': 'https://www.imdb.com//title/tt0024216/'},
#  {'budget': 16000000.0,
#   'cumulative_world_gross': 321310.0,
#   'date': '13 June 2013',
#   'genre': ['Action', 'Horror', 'Sci-Fi'],
#   'gross_usa': None,
#   'rating': 5.3,
#   'runtime': 95.0,
#   'title': 'The Colony',
#   'url': 'https://www.imdb.com//title/tt1160996/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': None,
#   'genre': None,
#   'gross_usa': None,
#   'rating': None,
#   'runtime': None,
#   'title': None,
#   'url': 'https://www.imdb.com//title/tt1716772/'},
#  {'budget': None,
#   'cumulative_world_gross': 6759803.0,
#   'date': '4 December 2009',
#   'genre': ['Adventure', 'Horror', 'Thriller'],
#   'gross_usa': None,
#   'rating': 5.8,
#   'runtime': 94.0,
#   'title': 'The Descent: Part 2',
#   'url': 'https://www.imdb.com//title/tt1073105/'},
#  {'budget': 87000000.0,
#   'cumulative_world_gross': 148336445.0,
#   'date': '3 October 2003',
#   'genre': ['Drama', 'History', 'Sport'],
#   'gross_usa': 120277854.0,
#   'rating': 7.3,
#   'runtime': 140.0,
#   'title': 'Seabiscuit',
#   'url': 'https://www.imdb.com//title/tt0329575/'},
#  {'budget': 30000000.0,
#   'cumulative_world_gross': 32917353.0,
#   'date': '13 January 2017',
#   'genre': ['Action', 'Crime', 'Thriller'],
#   'gross_usa': 20783704.0,
#   'rating': 5.6,
#   'runtime': None,
#   'title': 'Sleepless',
#   'url': 'https://www.imdb.com//title/tt2072233/'},
#  {'budget': 60000000.0,
#   'cumulative_world_gross': 69929545.0,
#   'date': '22 September 2016',
#   'genre': ['Animation', 'Action', 'Adventure'],
#   'gross_usa': 48023088.0,
#   'rating': 7.8,
#   'runtime': 101.0,
#   'title': 'Kubo - den modige samurai',
#   'url': 'https://www.imdb.com//title/tt4302938/'},
#  {'budget': 25000000.0,
#   'cumulative_world_gross': 175440.0,
#   'date': '4 March 2011',
#   'genre': ['Action', 'Drama', 'History'],
#   'gross_usa': None,
#   'rating': 6.1,
#   'runtime': 121.0,
#   'title': 'Ironclad',
#   'url': 'https://www.imdb.com//title/tt1233301/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': None,
#   'genre': None,
#   'gross_usa': None,
#   'rating': None,
#   'runtime': None,
#   'title': None,
#   'url': 'https://www.imdb.com//title/tt1531901/'},
#  {'budget': 18000000.0,
#   'cumulative_world_gross': 46708276.0,
#   'date': '8 October 1982',
#   'genre': ['Action', 'Adventure', 'Thriller'],
#   'gross_usa': 46708276.0,
#   'rating': 5.9,
#   'runtime': 136.0,
#   'title': 'Firefox',
#   'url': 'https://www.imdb.com//title/tt0083943/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': None,
#   'genre': None,
#   'gross_usa': None,
#   'rating': None,
#   'runtime': None,
#   'title': None,
#   'url': 'https://www.imdb.com//title/tt3808342/'},
#  {'budget': 25000000.0,
#   'cumulative_world_gross': 152699946.0,
#   'date': '2 March 2001',
#   'genre': ['Drama', 'Romance'],
#   'gross_usa': 71509363.0,
#   'rating': 7.2,
#   'runtime': 121.0,
#   'title': 'Chocolat',
#   'url': 'https://www.imdb.com//title/tt0241303/'},
#  {'budget': None,
#   'cumulative_world_gross': 21274717.0,
#   'date': '23 July 1993',
#   'genre': ['Comedy', 'Sci-Fi'],
#   'gross_usa': 21274717.0,
#   'rating': 5.3,
#   'runtime': 88.0,
#   'title': 'Coneheads',
#   'url': 'https://www.imdb.com//title/tt0106598/'},
#  {'budget': 25000000.0,
#   'cumulative_world_gross': 5776089.0,
#   'date': '9 January 2009',
#   'genre': ['Action', 'Crime', 'Thriller'],
#   'gross_usa': None,
#   'rating': 6.0,
#   'runtime': 104.0,
#   'title': 'Thick as Thieves',
#   'url': 'https://www.imdb.com//title/tt1112782/'},
#  {'budget': 100000000.0,
#   'cumulative_world_gross': 384335608.0,
#   'date': '8 December 2006',
#   'genre': ['Animation', 'Adventure', 'Comedy'],
#   'gross_usa': 198000317.0,
#   'rating': 6.4,
#   'runtime': 108.0,
#   'title': 'Happy Feet',
#   'url': 'https://www.imdb.com//title/tt0366548/'},
#  {'budget': 15000000.0,
#   'cumulative_world_gross': 201957688.0,
#   'date': '8 February 1991',
#   'genre': ['Comedy', 'Crime'],
#   'gross_usa': 91457688.0,
#   'rating': 6.1,
#   'runtime': 111.0,
#   'title': 'Strømer i børnehaveklassen',
#   'url': 'https://www.imdb.com//title/tt0099938/'},
#  {'budget': 20000000.0,
#   'cumulative_world_gross': 100375432.0,
#   'date': '31 July 2014',
#   'genre': ['Comedy', 'Romance'],
#   'gross_usa': 84525432.0,
#   'rating': 4.9,
#   'runtime': 97.0,
#   'title': 'Tammy',
#   'url': 'https://www.imdb.com//title/tt2103254/'},
#  {'budget': 48000000.0,
#   'cumulative_world_gross': 220673217.0,
#   'date': '2 January 2004',
#   'genre': ['Comedy'],
#   'gross_usa': 110003217.0,
#   'rating': 5.5,
#   'runtime': 84.0,
#   'title': 'Scary Movie 3',
#   'url': 'https://www.imdb.com//title/tt0306047/'},
#  {'budget': 40000000.0,
#   'cumulative_world_gross': 151161491.0,
#   'date': '22 February 2008',
#   'genre': ['Action', 'Crime', 'Drama'],
#   'gross_usa': 72266306.0,
#   'rating': 6.6,
#   'runtime': 90.0,
#   'title': 'Vantage Point',
#   'url': 'https://www.imdb.com//title/tt0443274/'},
#  {'budget': 25000000.0,
#   'cumulative_world_gross': 11603545.0,
#   'date': '11 April 1986',
#   'genre': ['Action', 'Horror', 'Mystery'],
#   'gross_usa': 11603545.0,
#   'rating': 6.1,
#   'runtime': 101.0,
#   'title': 'Livsfarlig invasion',
#   'url': 'https://www.imdb.com//title/tt0089489/'},
#  {'budget': 2000000.0,
#   'cumulative_world_gross': 599146.0,
#   'date': '8 October 1963',
#   'genre': ['Crime', 'Drama'],
#   'gross_usa': 592237.0,
#   'rating': 8.3,
#   'runtime': 129.0,
#   'title': 'Dræb ikke en sangfugl',
#   'url': 'https://www.imdb.com//title/tt0056592/'},
#  {'budget': 5000000.0,
#   'cumulative_world_gross': 161919318.0,
#   'date': '28 November 2013',
#   'genre': ['Horror', 'Mystery', 'Thriller'],
#   'gross_usa': 83586447.0,
#   'rating': 6.6,
#   'runtime': 106.0,
#   'title': 'Insidious 2',
#   'url': 'https://www.imdb.com//title/tt2226417/'},
#  {'budget': 33000000.0,
#   'cumulative_world_gross': 54700105.0,
#   'date': '16 July 2004',
#   'genre': ['Action', 'Crime', 'Drama'],
#   'gross_usa': 33810189.0,
#   'rating': 6.4,
#   'runtime': 124.0,
#   'title': 'The Punisher',
#   'url': 'https://www.imdb.com//title/tt0330793/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': None,
#   'genre': None,
#   'gross_usa': None,
#   'rating': None,
#   'runtime': None,
#   'title': None,
#   'url': 'https://www.imdb.com//title/tt3262342/'},
#  {'budget': 34000000.0,
#   'cumulative_world_gross': 41142379.0,
#   'date': '2 August 2018',
#   'genre': ['Action', 'Adventure', 'Drama'],
#   'gross_usa': 12695691.0,
#   'rating': 5.7,
#   'runtime': 104.0,
#   'title': 'The Darkest Minds',
#   'url': 'https://www.imdb.com//title/tt4073790/'},
#  {'budget': 9400000.0,
#   'cumulative_world_gross': None,
#   'date': '31 July 2015',
#   'genre': ['Crime', 'Drama', 'Mystery'],
#   'gross_usa': None,
#   'rating': 8.3,
#   'runtime': 163.0,
#   'title': 'Drishyam',
#   'url': 'https://www.imdb.com//title/tt4430212/'},
#  {'budget': 13000000.0,
#   'cumulative_world_gross': 49369899.0,
#   'date': '6 February 1989',
#   'genre': ['Horror'],
#   'gross_usa': 49369899.0,
#   'rating': 5.7,
#   'runtime': 93.0,
#   'title': 'Søvnløse nætter',
#   'url': 'https://www.imdb.com//title/tt0095742/'},
#  {'budget': 24000000.0,
#   'cumulative_world_gross': 17612099.0,
#   'date': '29 August 2018',
#   'genre': ['Biography', 'Drama', 'History'],
#   'gross_usa': 17612099.0,
#   'rating': 6.5,
#   'runtime': None,
#   'title': 'Operation Finale',
#   'url': 'https://www.imdb.com//title/tt5208252/'},
#  {'budget': 4000000.0,
#   'cumulative_world_gross': 179836.0,
#   'date': '12 June 2009',
#   'genre': ['Comedy', 'Horror', 'Sci-Fi'],
#   'gross_usa': None,
#   'rating': 6.0,
#   'runtime': 89.0,
#   'title': 'Doghouse',
#   'url': 'https://www.imdb.com//title/tt1023500/'},
#  {'budget': 65000000.0,
#   'cumulative_world_gross': 89456761.0,
#   'date': '25 December 1996',
#   'genre': ['Action', 'Crime', 'Drama'],
#   'gross_usa': 33447612.0,
#   'rating': 6.8,
#   'runtime': 121.0,
#   'title': 'The Long Kiss Goodnight',
#   'url': 'https://www.imdb.com//title/tt0116908/'},
#  {'budget': None,
#   'cumulative_world_gross': 6879098.0,
#   'date': '2 October 2015',
#   'genre': ['Crime', 'Drama', 'Mystery'],
#   'gross_usa': 342370.0,
#   'rating': 8.2,
#   'runtime': 132.0,
#   'title': 'Talvar',
#   'url': 'https://www.imdb.com//title/tt4934950/'},
#  {'budget': 900000.0,
#   'cumulative_world_gross': 17385830.0,
#   'date': '2 January 2014',
#   'genre': ['Biography', 'Drama', 'Romance'],
#   'gross_usa': 16101339.0,
#   'rating': 7.5,
#   'runtime': 85.0,
#   'title': 'Fruitvale Station',
#   'url': 'https://www.imdb.com//title/tt2334649/'},
#  {'budget': 1500000.0,
#   'cumulative_world_gross': 95461.0,
#   'date': '18 March 1974',
#   'genre': ['Drama', 'Horror', 'Thriller'],
#   'gross_usa': None,
#   'rating': 7.3,
#   'runtime': 110.0,
#   'title': 'Rødt chok',
#   'url': 'https://www.imdb.com//title/tt0069995/'},
#  {'budget': None,
#   'cumulative_world_gross': 113164.0,
#   'date': '30 October 1986',
#   'genre': ['Action', 'Comedy', 'Crime'],
#   'gross_usa': 113164.0,
#   'rating': 7.6,
#   'runtime': 100.0,
#   'title': "Police Story - En strømer ta'r hævn",
#   'url': 'https://www.imdb.com//title/tt0089374/'},
#  {'budget': 3000000.0,
#   'cumulative_world_gross': 921752.0,
#   'date': '2 March 2012',
#   'genre': ['Horror', 'Thriller'],
#   'gross_usa': 3010.0,
#   'rating': 4.7,
#   'runtime': 90.0,
#   'title': 'ATM',
#   'url': 'https://www.imdb.com//title/tt1603257/'},
#  {'budget': 3000000.0,
#   'cumulative_world_gross': None,
#   'date': '21 February 1963',
#   'genre': ['Drama', 'Thriller'],
#   'gross_usa': None,
#   'rating': 7.7,
#   'runtime': 106.0,
#   'title': 'Frygtens terror',
#   'url': 'https://www.imdb.com//title/tt0055824/'},
#  {'budget': None,
#   'cumulative_world_gross': 5776640.0,
#   'date': '11 September 2014',
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'gross_usa': 5284309.0,
#   'rating': 6.8,
#   'runtime': 93.0,
#   'title': 'The Skeleton Twins',
#   'url': 'https://www.imdb.com//title/tt1571249/'},
#  {'budget': 1000000.0,
#   'cumulative_world_gross': 79624.0,
#   'date': '15 January 2015',
#   'genre': ['Drama', 'War'],
#   'gross_usa': 13302.0,
#   'rating': 6.9,
#   'runtime': 117.0,
#   'title': 'Camp X-Ray',
#   'url': 'https://www.imdb.com//title/tt2994190/'},
#  {'budget': 35000000.0,
#   'cumulative_world_gross': 94728529.0,
#   'date': '11 April 2001',
#   'genre': ['Comedy', 'Romance'],
#   'gross_usa': 60400856.0,
#   'rating': 5.3,
#   'runtime': 103.0,
#   'title': 'The Wedding Planner',
#   'url': 'https://www.imdb.com//title/tt0209475/'},
#  {'budget': 30000000.0,
#   'cumulative_world_gross': 41002607.0,
#   'date': '15 September 2011',
#   'genre': ['Comedy', 'Horror'],
#   'gross_usa': 18302607.0,
#   'rating': 6.3,
#   'runtime': 106.0,
#   'title': 'Fright Night',
#   'url': 'https://www.imdb.com//title/tt1438176/'},
#  {'budget': 150000000.0,
#   'cumulative_world_gross': 385680446.0,
#   'date': '8 May 2009',
#   'genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'gross_usa': 257730019.0,
#   'rating': 7.9,
#   'runtime': 127.0,
#   'title': 'Star Trek',
#   'url': 'https://www.imdb.com//title/tt0796366/'},
#  {'budget': 13800000.0,
#   'cumulative_world_gross': 52293982.0,
#   'date': '13 March 1987',
#   'genre': ['Drama', 'Sport'],
#   'gross_usa': 52293982.0,
#   'rating': 7.0,
#   'runtime': 119.0,
#   'title': 'Det handler om penge',
#   'url': 'https://www.imdb.com//title/tt0090863/'},
#  {'budget': 155000000.0,
#   'cumulative_world_gross': 167298192.0,
#   'date': '26 November 2004',
#   'genre': ['Action', 'Biography', 'Drama'],
#   'gross_usa': 34297191.0,
#   'rating': 5.6,
#   'runtime': 175.0,
#   'title': 'Alexander',
#   'url': 'https://www.imdb.com//title/tt0346491/'},
#  {'budget': 20000000.0,
#   'cumulative_world_gross': 24991167.0,
#   'date': '11 May 2007',
#   'genre': ['Comedy', 'Drama'],
#   'gross_usa': 19103072.0,
#   'rating': 5.8,
#   'runtime': None,
#   'title': 'Georgia Rule',
#   'url': 'https://www.imdb.com//title/tt0791304/'},
#  {'budget': 40000000.0,
#   'cumulative_world_gross': 91636986.0,
#   'date': '19 June 2009',
#   'genre': ['Comedy', 'Romance'],
#   'gross_usa': 71440011.0,
#   'rating': 7.0,
#   'runtime': 105.0,
#   'title': 'I Love You, Man',
#   'url': 'https://www.imdb.com//title/tt1155056/'},
#  {'budget': 20000000.0,
#   'cumulative_world_gross': 153698625.0,
#   'date': '4 February 1994',
#   'genre': ['Adventure', 'Drama', 'Family'],
#   'gross_usa': 77698625.0,
#   'rating': 5.9,
#   'runtime': 112.0,
#   'title': 'Befri Willy',
#   'url': 'https://www.imdb.com//title/tt0106965/'},
#  {'budget': 8500000.0,
#   'cumulative_world_gross': 828850.0,
#   'date': '14 March 2014',
#   'genre': ['Comedy', 'Drama', 'Fantasy'],
#   'gross_usa': 257706.0,
#   'rating': 6.1,
#   'runtime': 107.0,
#   'title': 'The Zero Theorem',
#   'url': 'https://www.imdb.com//title/tt2333804/'},
#  {'budget': 15000000.0,
#   'cumulative_world_gross': 118243066.0,
#   'date': '25 March 1994',
#   'genre': ['Comedy', 'Family', 'Romance'],
#   'gross_usa': 53443066.0,
#   'rating': 4.9,
#   'runtime': 89.0,
#   'title': 'Beethoven 2',
#   'url': 'https://www.imdb.com//title/tt0106375/'},
#  {'budget': 94000000.0,
#   'cumulative_world_gross': 2855644.0,
#   'date': '16 December 2011',
#   'genre': ['Drama', 'History', 'Romance'],
#   'gross_usa': 311434.0,
#   'rating': 7.6,
#   'runtime': 146.0,
#   'title': 'The Flowers of War',
#   'url': 'https://www.imdb.com//title/tt1410063/'},
#  {'budget': 12000000.0,
#   'cumulative_world_gross': 22939027.0,
#   'date': '16 February 2012',
#   'genre': ['Comedy', 'Drama'],
#   'gross_usa': 16311571.0,
#   'rating': 6.3,
#   'runtime': 94.0,
#   'title': 'Young Adult',
#   'url': 'https://www.imdb.com//title/tt1625346/'},
#  {'budget': 10000000.0,
#   'cumulative_world_gross': 31429330.0,
#   'date': '5 May 2000',
#   'genre': ['Adventure', 'Comedy', 'Drama'],
#   'gross_usa': 30652890.0,
#   'rating': 7.3,
#   'runtime': 130.0,
#   'title': 'Dogma',
#   'url': 'https://www.imdb.com//title/tt0120655/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': None,
#   'genre': None,
#   'gross_usa': None,
#   'rating': None,
#   'runtime': None,
#   'title': None,
#   'url': 'https://www.imdb.com//title/tt0108500/'},
#  {'budget': 39000000.0,
#   'cumulative_world_gross': 288752301.0,
#   'date': '16 September 1988',
#   'genre': ['Comedy', 'Romance'],
#   'gross_usa': 128152301.0,
#   'rating': 7.0,
#   'runtime': 116.0,
#   'title': 'Coming to America',
#   'url': 'https://www.imdb.com//title/tt0094898/'},
#  {'budget': 13000000.0,
#   'cumulative_world_gross': 35259653.0,
#   'date': '4 May 2016',
#   'genre': ['Drama', 'Thriller', 'War'],
#   'gross_usa': 18704595.0,
#   'rating': 7.3,
#   'runtime': 102.0,
#   'title': 'Eye in the Sky',
#   'url': 'https://www.imdb.com//title/tt2057392/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': None,
#   'genre': None,
#   'gross_usa': None,
#   'rating': None,
#   'runtime': None,
#   'title': None,
#   'url': 'https://www.imdb.com//title/tt0425112/'},
#  {'budget': None,
#   'cumulative_world_gross': 3154346.0,
#   'date': '9 September 2005',
#   'genre': ['Crime', 'Drama', 'Sport'],
#   'gross_usa': 346830.0,
#   'rating': 7.5,
#   'runtime': 109.0,
#   'title': 'Hooligans',
#   'url': 'https://www.imdb.com//title/tt0385002/'},
#  {'budget': 65000000.0,
#   'cumulative_world_gross': 156491279.0,
#   'date': '23 February 2012',
#   'genre': ['Action', 'Comedy', 'Romance'],
#   'gross_usa': 54760791.0,
#   'rating': 6.3,
#   'runtime': 97.0,
#   'title': 'This Means War',
#   'url': 'https://www.imdb.com//title/tt1596350/'},
#  {'budget': 10000000.0,
#   'cumulative_world_gross': 12252684.0,
#   'date': '8 April 2016',
#   'genre': ['Biography', 'Drama'],
#   'gross_usa': 3866794.0,
#   'rating': 7.2,
#   'runtime': 108.0,
#   'title': 'The Man Who Knew Infinity',
#   'url': 'https://www.imdb.com//title/tt0787524/'},
#  {'budget': 1752000.0,
#   'cumulative_world_gross': 299645.0,
#   'date': '25 January 1951',
#   'genre': ['Drama', 'Film-Noir'],
#   'gross_usa': 299645.0,
#   'rating': 8.4,
#   'runtime': 110.0,
#   'title': 'Sunset Boulevard',
#   'url': 'https://www.imdb.com//title/tt0043014/'},
#  {'budget': 19000000.0,
#   'cumulative_world_gross': 34612443.0,
#   'date': '25 December 2007',
#   'genre': ['Crime', 'Drama', 'Mystery'],
#   'gross_usa': 20292962.0,
#   'rating': 7.6,
#   'runtime': 114.0,
#   'title': 'Gone Baby Gone',
#   'url': 'https://www.imdb.com//title/tt0452623/'},
#  {'budget': None,
#   'cumulative_world_gross': 170323.0,
#   'date': 'November 2011',
#   'genre': ['Horror'],
#   'gross_usa': 141877.0,
#   'rating': 3.8,
#   'runtime': 91.0,
#   'title': 'The Human Centipede II (Full Sequence)',
#   'url': 'https://www.imdb.com//title/tt1530509/'},
#  {'budget': 90000000.0,
#   'cumulative_world_gross': 202292902.0,
#   'date': '26 March 1999',
#   'genre': ['Biography', 'Comedy', 'Drama'],
#   'gross_usa': 135026902.0,
#   'rating': 6.8,
#   'runtime': 115.0,
#   'title': 'Patch Adams',
#   'url': 'https://www.imdb.com//title/tt0129290/'},
#  {'budget': None,
#   'cumulative_world_gross': 176288.0,
#   'date': '6 October 2017',
#   'genre': ['Comedy', 'Crime', 'Horror'],
#   'gross_usa': 20369.0,
#   'rating': 6.5,
#   'runtime': 89.0,
#   'title': 'Better Watch Out',
#   'url': 'https://www.imdb.com//title/tt4443658/'},
#  {'budget': 58000000.0,
#   'cumulative_world_gross': 102854431.0,
#   'date': '9 December 2005',
#   'genre': ['Comedy', 'Drama', 'Fantasy'],
#   'gross_usa': 48318130.0,
#   'rating': 6.7,
#   'runtime': 95.0,
#   'title': 'Just Like Heaven',
#   'url': 'https://www.imdb.com//title/tt0425123/'},
#  {'budget': 175000000.0,
#   'cumulative_world_gross': 151783839.0,
#   'date': '13 March 2014',
#   'genre': ['Action', 'Drama', 'Fantasy'],
#   'gross_usa': 38362475.0,
#   'rating': 6.2,
#   'runtime': 119.0,
#   'title': '47 Ronin',
#   'url': 'https://www.imdb.com//title/tt1335975/'},
#  {'budget': 3000000.0,
#   'cumulative_world_gross': 145676.0,
#   'date': '20 April 2012',
#   'genre': ['Drama', 'Horror', 'Sci-Fi'],
#   'gross_usa': None,
#   'rating': 5.8,
#   'runtime': 112.0,
#   'title': 'The Divide',
#   'url': 'https://www.imdb.com//title/tt1535616/'},
#  {'budget': 20000000.0,
#   'cumulative_world_gross': 713616.0,
#   'date': '13 February 2013',
#   'genre': ['Drama', 'Mystery', 'Thriller'],
#   'gross_usa': 92181.0,
#   'rating': 5.3,
#   'runtime': 102.0,
#   'title': 'Passion',
#   'url': 'https://www.imdb.com//title/tt1829012/'},
#  {'budget': 30000000.0,
#   'cumulative_world_gross': 249083684.0,
#   'date': '16 April 2014',
#   'genre': ['Animation', 'Biography', 'Drama'],
#   'gross_usa': 5209580.0,
#   'rating': 7.8,
#   'runtime': 126.0,
#   'title': 'Når vinden rejser sig',
#   'url': 'https://www.imdb.com//title/tt2013293/'},
#  {'budget': 5000000.0,
#   'cumulative_world_gross': 8373672.0,
#   'date': '4 October 2013',
#   'genre': ['Comedy', 'Crime', 'Drama'],
#   'gross_usa': 34411.0,
#   'rating': 7.1,
#   'runtime': 97.0,
#   'title': 'Filth',
#   'url': 'https://www.imdb.com//title/tt1450321/'},
#  {'budget': 37000000.0,
#   'cumulative_world_gross': 37962774.0,
#   'date': '26 December 1986',
#   'genre': ['Action', 'Adventure', 'Comedy'],
#   'gross_usa': 16295774.0,
#   'rating': 4.7,
#   'runtime': 110.0,
#   'title': 'Howard - Helten over alle helte',
#   'url': 'https://www.imdb.com//title/tt0091225/'},
#  {'budget': 10000000.0,
#   'cumulative_world_gross': 9593903.0,
#   'date': '15 May 1998',
#   'genre': ['Drama', 'Mystery', 'Thriller'],
#   'gross_usa': 9593903.0,
#   'rating': 7.2,
#   'runtime': 110.0,
#   'title': 'The Spanish Prisoner',
#   'url': 'https://www.imdb.com//title/tt0120176/'},
#  {'budget': 1000000.0,
#   'cumulative_world_gross': 205715.0,
#   'date': '21 March 2014',
#   'genre': ['Action', 'Drama', 'Sci-Fi'],
#   'gross_usa': None,
#   'rating': 6.1,
#   'runtime': 91.0,
#   'title': 'The Machine',
#   'url': 'https://www.imdb.com//title/tt2317225/'},
#  {'budget': 44000000.0,
#   'cumulative_world_gross': 300400432.0,
#   'date': '25 October 1985',
#   'genre': ['Action', 'Adventure', 'Thriller'],
#   'gross_usa': 150415432.0,
#   'rating': 6.5,
#   'runtime': 96.0,
#   'title': 'Rambo: First Blood 2',
#   'url': 'https://www.imdb.com//title/tt0089880/'},
#  {'budget': 90000000.0,
#   'cumulative_world_gross': 199936011.0,
#   'date': '26 September 2008',
#   'genre': ['Comedy'],
#   'gross_usa': 100018837.0,
#   'rating': 5.5,
#   'runtime': 113.0,
#   'title': 'Zohan',
#   'url': 'https://www.imdb.com//title/tt0960144/'},
#  {'budget': 30000000.0,
#   'cumulative_world_gross': 53909751.0,
#   'date': '27 April 2012',
#   'genre': ['Comedy', 'Romance'],
#   'gross_usa': 28835528.0,
#   'rating': 6.2,
#   'runtime': 124.0,
#   'title': 'The Five-Year Engagement',
#   'url': 'https://www.imdb.com//title/tt1195478/'},
#  {'budget': 3000000.0,
#   'cumulative_world_gross': 21898920.0,
#   'date': '12 January 1996',
#   'genre': ['Biography', 'Comedy', 'Drama'],
#   'gross_usa': 21848932.0,
#   'rating': 7.7,
#   'runtime': 108.0,
#   'title': 'Postbudet',
#   'url': 'https://www.imdb.com//title/tt0110877/'},
#  {'budget': 30000000.0,
#   'cumulative_world_gross': 84790678.0,
#   'date': '31 October 2013',
#   'genre': ['Drama', 'Horror'],
#   'gross_usa': 35266619.0,
#   'rating': 5.9,
#   'runtime': 100.0,
#   'title': 'Carrie',
#   'url': 'https://www.imdb.com//title/tt1939659/'},
#  {'budget': 38000000.0,
#   'cumulative_world_gross': 105648706.0,
#   'date': '8 October 2010',
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'gross_usa': 53374681.0,
#   'rating': 6.5,
#   'runtime': None,
#   'title': 'Life as We Know It',
#   'url': 'https://www.imdb.com//title/tt1055292/'},
#  {'budget': 40000000.0,
#   'cumulative_world_gross': 274176364.0,
#   'date': '16 November 1990',
#   'genre': ['Animation', 'Family', 'Fantasy'],
#   'gross_usa': 111543479.0,
#   'rating': 7.6,
#   'runtime': 83.0,
#   'title': 'Den lille havfrue',
#   'url': 'https://www.imdb.com//title/tt0097757/'},
#  {'budget': 10000000.0,
#   'cumulative_world_gross': 7804337.0,
#   'date': '28 March 2014',
#   'genre': ['Comedy', 'Drama'],
#   'gross_usa': 7779614.0,
#   'rating': 6.6,
#   'runtime': 89.0,
#   'title': 'Bad Words',
#   'url': 'https://www.imdb.com//title/tt2170299/'},
#  {'budget': 260000000.0,
#   'cumulative_world_gross': 591794936.0,
#   'date': '3 February 2011',
#   'genre': ['Animation', 'Adventure', 'Comedy'],
#   'gross_usa': 200821936.0,
#   'rating': 7.7,
#   'runtime': 100.0,
#   'title': 'To på flugt',
#   'url': 'https://www.imdb.com//title/tt0398286/'},
#  {'budget': 60000000.0,
#   'cumulative_world_gross': 204594016.0,
#   'date': '11 November 2010',
#   'genre': ['Drama', 'Romance'],
#   'gross_usa': 80574010.0,
#   'rating': 5.8,
#   'runtime': 133.0,
#   'title': 'Spis bed elsk',
#   'url': 'https://www.imdb.com//title/tt0879870/'},
#  {'budget': 40000000.0,
#   'cumulative_world_gross': 359126022.0,
#   'date': '5 August 2010',
#   'genre': ['Action', 'Drama', 'Family'],
#   'gross_usa': 176591618.0,
#   'rating': 6.2,
#   'runtime': 140.0,
#   'title': 'The Karate Kid',
#   'url': 'https://www.imdb.com//title/tt1155076/'},
#  {'budget': 100000000.0,
#   'cumulative_world_gross': 108040622.0,
#   'date': '26 March 2004',
#   'genre': ['Action', 'Adventure', 'Biography'],
#   'gross_usa': 67303450.0,
#   'rating': 6.7,
#   'runtime': 136.0,
#   'title': 'Hidalgo',
#   'url': 'https://www.imdb.com//title/tt0317648/'},
#  {'budget': 1100000.0,
#   'cumulative_world_gross': 1504286.0,
#   'date': '30 January 1987',
#   'genre': ['Comedy', 'Crime', 'Drama'],
#   'gross_usa': 1435668.0,
#   'rating': 7.8,
#   'runtime': 107.0,
#   'title': 'Down by Law',
#   'url': 'https://www.imdb.com//title/tt0090967/'},
#  {'budget': 115000000.0,
#   'cumulative_world_gross': 77628265.0,
#   'date': '1 November 2002',
#   'genre': ['Action', 'Drama', 'War'],
#   'gross_usa': 40914068.0,
#   'rating': 6.1,
#   'runtime': 134.0,
#   'title': 'Windtalkers',
#   'url': 'https://www.imdb.com//title/tt0245562/'},
#  {'budget': 14000000.0,
#   'cumulative_world_gross': 29612137.0,
#   'date': '14 April 2006',
#   'genre': ['Drama', 'History', 'Horror'],
#   'gross_usa': 16298046.0,
#   'rating': 5.0,
#   'runtime': 83.0,
#   'title': 'An American Haunting',
#   'url': 'https://www.imdb.com//title/tt0429573/'},
#  {'budget': 6000000.0,
#   'cumulative_world_gross': 24271196.0,
#   'date': '12 October 1990',
#   'genre': ['Action', 'Crime', 'Drama'],
#   'gross_usa': 24078196.0,
#   'rating': 6.2,
#   'runtime': 108.0,
#   'title': 'Lion - the Streetfighter',
#   'url': 'https://www.imdb.com//title/tt0100029/'},
#  {'budget': 45000000.0,
#   'cumulative_world_gross': 178262620.0,
#   'date': '12 April 2006',
#   'genre': ['Comedy'],
#   'gross_usa': 90710620.0,
#   'rating': 5.0,
#   'runtime': 83.0,
#   'title': 'Scary Movie 4',
#   'url': 'https://www.imdb.com//title/tt0362120/'},
#  {'budget': 30000000.0,
#   'cumulative_world_gross': 82150642.0,
#   'date': '15 January 1999',
#   'genre': ['Biography', 'Drama', 'History'],
#   'gross_usa': 30082699.0,
#   'rating': 7.4,
#   'runtime': 124.0,
#   'title': 'Elizabeth',
#   'url': 'https://www.imdb.com//title/tt0127536/'},
#  {'budget': 57000000.0,
#   'cumulative_world_gross': 62112895.0,
#   'date': '9 November 2001',
#   'genre': ['Drama', 'Music', 'Romance'],
#   'gross_usa': 25543895.0,
#   'rating': 5.9,
#   'runtime': 131.0,
#   'title': 'Kaptajn Corellis mandolin',
#   'url': 'https://www.imdb.com//title/tt0238112/'},
#  {'budget': None,
#   'cumulative_world_gross': 10804315.0,
#   'date': '23 September 2005',
#   'genre': ['Biography', 'Crime', 'Drama'],
#   'gross_usa': 680331.0,
#   'rating': 7.6,
#   'runtime': 120.0,
#   'title': 'Sophie Scholl - de sidste dage',
#   'url': 'https://www.imdb.com//title/tt0426578/'},
#  {'budget': 6000000.0,
#   'cumulative_world_gross': 10994533.0,
#   'date': '5 July 2002',
#   'genre': ['Biography', 'Drama'],
#   'gross_usa': 8598593.0,
#   'rating': 7.0,
#   'runtime': 122.0,
#   'title': 'Pollock',
#   'url': 'https://www.imdb.com//title/tt0183659/'},
#  {'budget': 20000000.0,
#   'cumulative_world_gross': 72258126.0,
#   'date': '4 June 2004',
#   'genre': ['Drama', 'Romance', 'Sci-Fi'],
#   'gross_usa': 34400301.0,
#   'rating': 8.3,
#   'runtime': 108.0,
#   'title': 'Evigt solskin i et pletfrit sind',
#   'url': 'https://www.imdb.com//title/tt0338013/'},
#  {'budget': None,
#   'cumulative_world_gross': 29119434.0,
#   'date': '19 September 2003',
#   'genre': ['Drama', 'Mystery', 'Thriller'],
#   'gross_usa': 21386011.0,
#   'rating': 5.0,
#   'runtime': 118.0,
#   'title': 'Cold Creek Manor',
#   'url': 'https://www.imdb.com//title/tt0331468/'},
#  {'budget': 40000000.0,
#   'cumulative_world_gross': 105962760.0,
#   'date': '16 May 2008',
#   'genre': ['Comedy', 'Romance'],
#   'gross_usa': 46012734.0,
#   'rating': 5.9,
#   'runtime': 101.0,
#   'title': 'En ægte mand',
#   'url': 'https://www.imdb.com//title/tt0866439/'},
#  {'budget': 2540800.0,
#   'cumulative_world_gross': 1841438.0,
#   'date': '20 October 1952',
#   'genre': ['Comedy', 'Musical', 'Romance'],
#   'gross_usa': 1826108.0,
#   'rating': 8.3,
#   'runtime': 103.0,
#   'title': 'Syng i sol og regn',
#   'url': 'https://www.imdb.com//title/tt0045152/'},
#  {'budget': 30000000.0,
#   'cumulative_world_gross': 81613606.0,
#   'date': '28 October 1988',
#   'genre': ['Action', 'Comedy', 'Crime'],
#   'gross_usa': 38413606.0,
#   'rating': 7.5,
#   'runtime': 126.0,
#   'title': 'Midnight Run',
#   'url': 'https://www.imdb.com//title/tt0095631/'},
#  {'budget': 27000000.0,
#   'cumulative_world_gross': 20250857.0,
#   'date': '26 December 1984',
#   'genre': ['Adventure', 'Drama', 'Family'],
#   'gross_usa': 20158808.0,
#   'rating': 7.4,
#   'runtime': 102.0,
#   'title': 'Den uendelige historie',
#   'url': 'https://www.imdb.com//title/tt0088323/'},
#  {'budget': 6000000.0,
#   'cumulative_world_gross': 54766923.0,
#   'date': '23 March 1981',
#   'genre': ['Drama'],
#   'gross_usa': 54766923.0,
#   'rating': 7.7,
#   'runtime': 124.0,
#   'title': 'Ordinary People: En ganske almindelig familie',
#   'url': 'https://www.imdb.com//title/tt0081283/'},
#  {'budget': 3000000.0,
#   'cumulative_world_gross': 1163969.0,
#   'date': '29 July 1994',
#   'genre': ['Comedy', 'Crime'],
#   'gross_usa': 1108462.0,
#   'rating': 7.3,
#   'runtime': 103.0,
#   'title': 'Heathers',
#   'url': 'https://www.imdb.com//title/tt0097493/'},
#  {'budget': 10000000.0,
#   'cumulative_world_gross': 14749758.0,
#   'date': '1 December 2006',
#   'genre': ['Horror', 'Mystery', 'Thriller'],
#   'gross_usa': 7027762.0,
#   'rating': 5.4,
#   'runtime': 93.0,
#   'title': 'Turistas',
#   'url': 'https://www.imdb.com//title/tt0454970/'},
#  {'budget': 35000000.0,
#   'cumulative_world_gross': 118071125.0,
#   'date': '3 March 1995',
#   'genre': ['Action', 'Adventure', 'Mystery'],
#   'gross_usa': 75671125.0,
#   'rating': 6.6,
#   'runtime': 118.0,
#   'title': 'Star Trek Generations',
#   'url': 'https://www.imdb.com//title/tt0111280/'},
#  {'budget': None,
#   'cumulative_world_gross': 8974829.0,
#   'date': '5 January 2007',
#   'genre': ['Crime', 'Drama', 'Romance'],
#   'gross_usa': 930469.0,
#   'rating': 6.5,
#   'runtime': 120.0,
#   'title': 'Breaking and Entering',
#   'url': 'https://www.imdb.com//title/tt0443456/'},
#  {'budget': 15000000.0,
#   'cumulative_world_gross': 16137046.0,
#   'date': '5 November 2015',
#   'genre': ['Action', 'Comedy', 'Horror'],
#   'gross_usa': 3703046.0,
#   'rating': 6.3,
#   'runtime': 93.0,
#   'title': 'Scouts Guide to the Zombie Apocalypse',
#   'url': 'https://www.imdb.com//title/tt1727776/'},
#  {'budget': 185000000.0,
#   'cumulative_world_gross': 538983207.0,
#   'date': '30 August 2012',
#   'genre': ['Animation', 'Adventure', 'Comedy'],
#   'gross_usa': 237283207.0,
#   'rating': 7.1,
#   'runtime': 93.0,
#   'title': 'Modig',
#   'url': 'https://www.imdb.com//title/tt1217209/'},
#  {'budget': None,
#   'cumulative_world_gross': 25382911.0,
#   'date': '16 January 2004',
#   'genre': ['Drama'],
#   'gross_usa': 15539656.0,
#   'rating': 7.7,
#   'runtime': 105.0,
#   'title': 'In America',
#   'url': 'https://www.imdb.com//title/tt0298845/'},
#  {'budget': 10000000.0,
#   'cumulative_world_gross': 32100816.0,
#   'date': '28 August 1992',
#   'genre': ['Horror', 'Sci-Fi'],
#   'gross_usa': 32100816.0,
#   'rating': 5.4,
#   'runtime': 108.0,
#   'title': 'Manden med plæneklipperen',
#   'url': 'https://www.imdb.com//title/tt0104692/'},
#  {'budget': 25000000.0,
#   'cumulative_world_gross': 78656813.0,
#   'date': '19 July 1991',
#   'genre': ['Action', 'Adventure', 'Comedy'],
#   'gross_usa': 78656813.0,
#   'rating': 6.0,
#   'runtime': 88.0,
#   'title': 'Turtles II - Gåden om det grønne slam',
#   'url': 'https://www.imdb.com//title/tt0103060/'},
#  {'budget': None,
#   'cumulative_world_gross': 2227167.0,
#   'date': '25 December 2013',
#   'genre': ['Drama'],
#   'gross_usa': 327167.0,
#   'rating': 6.7,
#   'runtime': 124.0,
#   'title': 'Nymphomaniac: Vol. II',
#   'url': 'https://www.imdb.com//title/tt2382009/'},
#  {'budget': 22000000.0,
#   'cumulative_world_gross': 80693537.0,
#   'date': '29 March 2002',
#   'genre': ['Drama', 'Family', 'Sport'],
#   'gross_usa': 75600072.0,
#   'rating': 6.9,
#   'runtime': 127.0,
#   'title': 'The Rookie',
#   'url': 'https://www.imdb.com//title/tt0265662/'},
#  {'budget': 24000000.0,
#   'cumulative_world_gross': 50236831.0,
#   'date': '15 July 1994',
#   'genre': ['Comedy', 'Family', 'Fantasy'],
#   'gross_usa': 50236831.0,
#   'rating': 6.1,
#   'runtime': 102.0,
#   'title': 'Engle på spil',
#   'url': 'https://www.imdb.com//title/tt0109127/'},
#  {'budget': 80000000.0,
#   'cumulative_world_gross': 336002996.0,
#   'date': '29 September 2006',
#   'genre': ['Animation', 'Adventure', 'Comedy'],
#   'gross_usa': 155019340.0,
#   'rating': 6.7,
#   'runtime': 83.0,
#   'title': 'Over hækken',
#   'url': 'https://www.imdb.com//title/tt0327084/'},
#  {'budget': 26000000.0,
#   'cumulative_world_gross': 181489203.0,
#   'date': '17 January 1997',
#   'genre': ['Comedy'],
#   'gross_usa': 105489203.0,
#   'rating': 6.4,
#   'runtime': 103.0,
#   'title': 'Ekskonernes klub',
#   'url': 'https://www.imdb.com//title/tt0116313/'},
#  {'budget': 70000000.0,
#   'cumulative_world_gross': 50732945.0,
#   'date': '1 November 2002',
#   'genre': ['Action', 'Adventure', 'Comedy'],
#   'gross_usa': 33561137.0,
#   'rating': 5.4,
#   'runtime': 97.0,
#   'title': 'I Spy',
#   'url': 'https://www.imdb.com//title/tt0297181/'},
#  {'budget': None,
#   'cumulative_world_gross': 11674.0,
#   'date': '16 November 1955',
#   'genre': ['Drama'],
#   'gross_usa': None,
#   'rating': 8.0,
#   'runtime': 108.0,
#   'title': 'La strada',
#   'url': 'https://www.imdb.com//title/tt0047528/'},
#  {'budget': 18000000.0,
#   'cumulative_world_gross': 12000000.0,
#   'date': '26 December 1981',
#   'genre': ['Mystery', 'Thriller'],
#   'gross_usa': 12000000.0,
#   'rating': 7.4,
#   'runtime': 108.0,
#   'title': 'Døden sletter alle spor',
#   'url': 'https://www.imdb.com//title/tt0082085/'},
#  {'budget': 4000000.0,
#   'cumulative_world_gross': 12571431.0,
#   'date': '2 December 2010',
#   'genre': ['Crime', 'Drama', 'Mystery'],
#   'gross_usa': None,
#   'rating': 7.4,
#   'runtime': 140.0,
#   'title': 'Av Mevsimi',
#   'url': 'https://www.imdb.com//title/tt1668191/'},
#  {'budget': 11000000.0,
#   'cumulative_world_gross': 775512064.0,
#   'date': '26 December 1977',
#   'genre': ['Action', 'Adventure', 'Fantasy'],
#   'gross_usa': 460998507.0,
#   'rating': 8.6,
#   'runtime': 121.0,
#   'title': 'Stjernekrigen',
#   'url': 'https://www.imdb.com//title/tt0076759/'},
#  {'budget': None,
#   'cumulative_world_gross': 2035468.0,
#   'date': '7 September 2007',
#   'genre': ['Crime', 'Drama'],
#   'gross_usa': 517809.0,
#   'rating': 7.0,
#   'runtime': 100.0,
#   'title': 'A Guide to Recognizing Your Saints',
#   'url': 'https://www.imdb.com//title/tt0473488/'},
#  {'budget': 12000000.0,
#   'cumulative_world_gross': 3769990.0,
#   'date': '14 August 1987',
#   'genre': ['Action', 'Comedy', 'Fantasy'],
#   'gross_usa': 3769990.0,
#   'rating': 7.1,
#   'runtime': 79.0,
#   'title': 'Min bedste ven, Frankenstein',
#   'url': 'https://www.imdb.com//title/tt0093560/'},
#  {'budget': 105000000.0,
#   'cumulative_world_gross': 171757863.0,
#   'date': '20 November 1998',
#   'genre': ['Animation', 'Adventure', 'Comedy'],
#   'gross_usa': 90757863.0,
#   'rating': 6.5,
#   'runtime': 83.0,
#   'title': 'Antz',
#   'url': 'https://www.imdb.com//title/tt0120587/'},
#  {'budget': 20000000.0,
#   'cumulative_world_gross': 18432000.0,
#   'date': '13 September 1985',
#   'genre': ['Adventure', 'Comedy', 'Drama'],
#   'gross_usa': 18432000.0,
#   'rating': 7.0,
#   'runtime': 121.0,
#   'title': 'Ladyhawke og lommetyven',
#   'url': 'https://www.imdb.com//title/tt0089457/'},
#  {'budget': 2800000.0,
#   'cumulative_world_gross': 19170001.0,
#   'date': '13 May 1988',
#   'genre': ['Horror', 'Thriller'],
#   'gross_usa': 19170001.0,
#   'rating': 5.3,
#   'runtime': 88.0,
#   'title': 'Friday the 13th Part VII: The New Blood',
#   'url': 'https://www.imdb.com//title/tt0095179/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': '25 August 2017',
#   'genre': ['Adventure', 'Crime', 'Drama'],
#   'gross_usa': None,
#   'rating': 4.5,
#   'runtime': 101.0,
#   'title': 'Death Note',
#   'url': 'https://www.imdb.com//title/tt1241317/'},
#  {'budget': 35000000.0,
#   'cumulative_world_gross': 57756408.0,
#   'date': '15 June 2001',
#   'genre': ['Comedy', 'Crime', 'Romance'],
#   'gross_usa': 40336607.0,
#   'rating': 6.2,
#   'runtime': 123.0,
#   'title': 'Heartbreakers',
#   'url': 'https://www.imdb.com//title/tt0125022/'},
#  {'budget': 15000000.0,
#   'cumulative_world_gross': 146428180.0,
#   'date': '20 June 2013',
#   'genre': ['Horror', 'Thriller'],
#   'gross_usa': 71628180.0,
#   'rating': 6.2,
#   'runtime': 100.0,
#   'title': 'Mama',
#   'url': 'https://www.imdb.com//title/tt2023587/'},
#  {'budget': None,
#   'cumulative_world_gross': 15089448.0,
#   'date': '29 April 2010',
#   'genre': ['Action', 'Biography', 'Drama'],
#   'gross_usa': 205675.0,
#   'rating': 7.5,
#   'runtime': 108.0,
#   'title': 'Yip Man 2',
#   'url': 'https://www.imdb.com//title/tt1386932/'},
#  {'budget': 900000.0,
#   'cumulative_world_gross': 2023414.0,
#   'date': '18 October 1985',
#   'genre': ['Comedy', 'Horror', 'Sci-Fi'],
#   'gross_usa': 2023414.0,
#   'rating': 7.2,
#   'runtime': 86.0,
#   'title': 'Re-Animator',
#   'url': 'https://www.imdb.com//title/tt0089885/'},
#  {'budget': 45000000.0,
#   'cumulative_world_gross': 101393569.0,
#   'date': '1 April 2005',
#   'genre': ['Action', 'Comedy', 'Crime'],
#   'gross_usa': 48478006.0,
#   'rating': 5.1,
#   'runtime': 115.0,
#   'title': 'Agent Catwalk 2 - farlig og forrygende',
#   'url': 'https://www.imdb.com//title/tt0385307/'},
#  {'budget': None,
#   'cumulative_world_gross': 33086611.0,
#   'date': '7 February 1986',
#   'genre': ['Comedy', 'Fantasy'],
#   'gross_usa': 33086611.0,
#   'rating': 6.1,
#   'runtime': 91.0,
#   'title': 'Teen Wolf: han er bare et hår bedre',
#   'url': 'https://www.imdb.com//title/tt0090142/'},
#  {'budget': 923000.0,
#   'cumulative_world_gross': 26916.0,
#   'date': '16 November 1925',
#   'genre': ['Adventure', 'Comedy', 'Drama'],
#   'gross_usa': None,
#   'rating': 8.2,
#   'runtime': 95.0,
#   'title': 'Guldfeber',
#   'url': 'https://www.imdb.com//title/tt0015864/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': '17 November 1924',
#   'genre': ['Action', 'Comedy', 'Romance'],
#   'gross_usa': 977375.0,
#   'rating': 8.2,
#   'runtime': 45.0,
#   'title': 'Sherlock Holmes, junior',
#   'url': 'https://www.imdb.com//title/tt0015324/'},
#  {'budget': 20000000.0,
#   'cumulative_world_gross': 49779728.0,
#   'date': '17 June 2010',
#   'genre': ['Comedy', 'Romance'],
#   'gross_usa': 32010860.0,
#   'rating': 6.4,
#   'runtime': None,
#   'title': 'Overscoring',
#   'url': 'https://www.imdb.com//title/tt0815236/'},
#  {'budget': 475000.0,
#   'cumulative_world_gross': None,
#   'date': '11 April 1986',
#   'genre': ['Action', 'Comedy', 'Horror'],
#   'gross_usa': None,
#   'rating': 6.3,
#   'runtime': 82.0,
#   'title': 'The Toxic Avenger',
#   'url': 'https://www.imdb.com//title/tt0090190/'},
#  {'budget': 42000000.0,
#   'cumulative_world_gross': 131457147.0,
#   'date': '6 December 2018',
#   'genre': ['Comedy', 'Fantasy', 'Horror'],
#   'gross_usa': 68549695.0,
#   'rating': 6.0,
#   'runtime': 105.0,
#   'title': 'The House with a Clock in Its Walls',
#   'url': 'https://www.imdb.com//title/tt2119543/'},
#  {'budget': 40000000.0,
#   'cumulative_world_gross': 14494036.0,
#   'date': '30 April 2004',
#   'genre': ['Comedy'],
#   'gross_usa': 13562325.0,
#   'rating': 4.8,
#   'runtime': 99.0,
#   'title': 'Envy',
#   'url': 'https://www.imdb.com//title/tt0326856/'},
#  {'budget': 10990000.0,
#   'cumulative_world_gross': None,
#   'date': '10 January 2014',
#   'genre': ['Action', 'Thriller'],
#   'gross_usa': None,
#   'rating': 8.2,
#   'runtime': 170.0,
#   'title': '1 - Nenokkadine',
#   'url': 'https://www.imdb.com//title/tt2375559/'},
#  {'budget': None,
#   'cumulative_world_gross': 21791288.0,
#   'date': '16 September 2009',
#   'genre': ['Comedy', 'Romance'],
#   'gross_usa': None,
#   'rating': 6.3,
#   'runtime': 95.0,
#   'title': 'The Rebound',
#   'url': 'https://www.imdb.com//title/tt1205535/'},
#  {'budget': None,
#   'cumulative_world_gross': 16712.0,
#   'date': '14 October 1946',
#   'genre': ['Drama', 'Thriller', 'War'],
#   'gross_usa': None,
#   'rating': 8.1,
#   'runtime': 103.0,
#   'title': 'Aaben By',
#   'url': 'https://www.imdb.com//title/tt0038890/'},
#  {'budget': 2500000.0,
#   'cumulative_world_gross': 357750.0,
#   'date': '16 March 1962',
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'gross_usa': None,
#   'rating': 7.7,
#   'runtime': 115.0,
#   'title': 'Pigen Holly',
#   'url': 'https://www.imdb.com//title/tt0054698/'},
#  {'budget': 30000000.0,
#   'cumulative_world_gross': 61808775.0,
#   'date': '25 December 2009',
#   'genre': ['Adventure', 'Comedy', 'Fantasy'],
#   'gross_usa': 7689607.0,
#   'rating': 6.8,
#   'runtime': 123.0,
#   'title': 'The Imaginarium of Dr. Parnassus',
#   'url': 'https://www.imdb.com//title/tt1054606/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': '29 June 2018',
#   'genre': ['Sci-Fi', 'Thriller'],
#   'gross_usa': None,
#   'rating': 5.8,
#   'runtime': 97.0,
#   'title': 'Tau',
#   'url': 'https://www.imdb.com//title/tt4357394/'},
#  {'budget': 560000.0,
#   'cumulative_world_gross': 2360561.0,
#   'date': '30 July 1964',
#   'genre': ['Comedy', 'Music', 'Musical'],
#   'gross_usa': 1480356.0,
#   'rating': 7.6,
#   'runtime': 87.0,
#   'title': 'En hård dags nat',
#   'url': 'https://www.imdb.com//title/tt0058182/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': None,
#   'genre': None,
#   'gross_usa': None,
#   'rating': None,
#   'runtime': None,
#   'title': None,
#   'url': 'https://www.imdb.com//title/tt0070215/'},
#  {'budget': 15700000.0,
#   'cumulative_world_gross': 23570541.0,
#   'date': '21 February 2013',
#   'genre': ['Biography', 'Comedy', 'Drama'],
#   'gross_usa': 6008677.0,
#   'rating': 6.8,
#   'runtime': 98.0,
#   'title': 'Hitchcock',
#   'url': 'https://www.imdb.com//title/tt0975645/'},
#  {'budget': 25000000.0,
#   'cumulative_world_gross': 56051920.0,
#   'date': '5 November 2004',
#   'genre': ['Action', 'Crime', 'Mystery'],
#   'gross_usa': 32003620.0,
#   'rating': 6.5,
#   'runtime': 94.0,
#   'title': 'Final Call',
#   'url': 'https://www.imdb.com//title/tt0337921/'},
#  {'budget': 50000000.0,
#   'cumulative_world_gross': 72617068.0,
#   'date': '2 December 2005',
#   'genre': ['Action', 'Crime', 'Drama'],
#   'gross_usa': 24149632.0,
#   'rating': 7.6,
#   'runtime': 122.0,
#   'title': 'Lord of War',
#   'url': 'https://www.imdb.com//title/tt0399295/'},
#  {'budget': 7000000.0,
#   'cumulative_world_gross': 7214806.0,
#   'date': '16 February 2017',
#   'genre': ['Comedy', 'Drama'],
#   'gross_usa': 5664764.0,
#   'rating': 7.3,
#   'runtime': 119.0,
#   'title': 'Alletiders kvinder',
#   'url': 'https://www.imdb.com//title/tt4385888/'},
#  {'budget': 30000000.0,
#   'cumulative_world_gross': 63372757.0,
#   'date': '2 May 2013',
#   'genre': ['Crime', 'Drama', 'Mystery'],
#   'gross_usa': 32172757.0,
#   'rating': 7.1,
#   'runtime': 106.0,
#   'title': 'Side Effects',
#   'url': 'https://www.imdb.com//title/tt2053463/'},
#  {'budget': None,
#   'cumulative_world_gross': 10597759.0,
#   'date': '9 February 1996',
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'gross_usa': 10597759.0,
#   'rating': 7.1,
#   'runtime': 112.0,
#   'title': 'Beautiful Girls',
#   'url': 'https://www.imdb.com//title/tt0115639/'},
#  {'budget': 5900000.0,
#   'cumulative_world_gross': 359891.0,
#   'date': '17 June 2016',
#   'genre': ['Action', 'Crime', 'Drama'],
#   'gross_usa': None,
#   'rating': 7.8,
#   'runtime': 148.0,
#   'title': 'Udta Punjab',
#   'url': 'https://www.imdb.com//title/tt4434004/'},
#  {'budget': 65000000.0,
#   'cumulative_world_gross': 90726668.0,
#   'date': '17 November 2000',
#   'genre': ['Drama', 'Romance'],
#   'gross_usa': 37761915.0,
#   'rating': 5.7,
#   'runtime': 103.0,
#   'title': 'Autumn in New York',
#   'url': 'https://www.imdb.com//title/tt0174480/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': '17 January 1972',
#   'genre': ['Action', 'Drama', 'Sci-Fi'],
#   'gross_usa': 8720000.0,
#   'rating': 6.5,
#   'runtime': 98.0,
#   'title': 'Sidste mand i live',
#   'url': 'https://www.imdb.com//title/tt0067525/'},
#  {'budget': 30000000.0,
#   'cumulative_world_gross': 51376861.0,
#   'date': '21 November 1997',
#   'genre': ['Action', 'Adventure', 'Fantasy'],
#   'gross_usa': 35927406.0,
#   'rating': 3.7,
#   'runtime': 95.0,
#   'title': 'Mortal Kombat: Annihilation',
#   'url': 'https://www.imdb.com//title/tt0119707/'},
#  {'budget': None,
#   'cumulative_world_gross': 1113538.0,
#   'date': '27 May 1981',
#   'genre': ['Drama', 'Horror'],
#   'gross_usa': 1113538.0,
#   'rating': 7.4,
#   'runtime': 124.0,
#   'title': 'Possession',
#   'url': 'https://www.imdb.com//title/tt0082933/'},
#  {'budget': 80000000.0,
#   'cumulative_world_gross': 33463969.0,
#   'date': '10 November 2000',
#   'genre': ['Action', 'Sci-Fi', 'Thriller'],
#   'gross_usa': 17480890.0,
#   'rating': 5.7,
#   'runtime': 106.0,
#   'title': 'Red Planet',
#   'url': 'https://www.imdb.com//title/tt0199753/'},
#  {'budget': None,
#   'cumulative_world_gross': 38956288.0,
#   'date': '13 October 1989',
#   'genre': ['Action', 'Drama', 'Family'],
#   'gross_usa': 38956288.0,
#   'rating': 5.2,
#   'runtime': 112.0,
#   'title': 'Karate Kid III',
#   'url': 'https://www.imdb.com//title/tt0097647/'},
#  {'budget': 73000000.0,
#   'cumulative_world_gross': 103891409.0,
#   'date': '30 October 1998',
#   'genre': ['Crime', 'Mystery', 'Thriller'],
#   'gross_usa': 55591409.0,
#   'rating': 6.0,
#   'runtime': 98.0,
#   'title': 'Snake Eyes',
#   'url': 'https://www.imdb.com//title/tt0120832/'},
#  {'budget': 5500000.0,
#   'cumulative_world_gross': 9629826.0,
#   'date': '26 August 2010',
#   'genre': ['Drama', 'Romance'],
#   'gross_usa': 1008098.0,
#   'rating': 7.6,
#   'runtime': 118.0,
#   'title': 'Hævnen',
#   'url': 'https://www.imdb.com//title/tt1340107/'},
#  {'budget': 2500000.0,
#   'cumulative_world_gross': None,
#   'date': '7 February 1974',
#   'genre': ['Comedy', 'Drama'],
#   'gross_usa': None,
#   'rating': 8.1,
#   'runtime': 102.0,
#   'title': 'Paper Moon',
#   'url': 'https://www.imdb.com//title/tt0070510/'},
#  {'budget': 10000000.0,
#   'cumulative_world_gross': 49998613.0,
#   'date': '26 December 1987',
#   'genre': ['Comedy', 'Family', 'Fantasy'],
#   'gross_usa': 29760613.0,
#   'rating': 6.0,
#   'runtime': 110.0,
#   'title': 'Bigfoot og familien Henderson',
#   'url': 'https://www.imdb.com//title/tt0093148/'},
#  {'budget': None,
#   'cumulative_world_gross': 273188.0,
#   'date': '20 October 1995',
#   'genre': ['Comedy', 'Drama', 'Music'],
#   'gross_usa': 273188.0,
#   'rating': 6.7,
# ...
#   'rating': 6.2,
#   'runtime': 98.0,
#   'title': 'Motorsavsmassakren',
#   'url': 'https://www.imdb.com//title/tt0324216/'},
#  {'budget': 30000000.0,
#   'cumulative_world_gross': 55583804.0,
#   'date': '26 February 2010',
#   'genre': ['Action', 'Comedy', 'Crime'],
#   'gross_usa': 44875481.0,
#   'rating': 5.6,
#   'runtime': 107.0,
#   'title': 'Cop Out',
#   'url': 'https://www.imdb.com//title/tt1385867/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': None,
#   'genre': None,
#   'gross_usa': None,
#   'rating': None,
#   'runtime': None,
#   'title': None,
#   'url': 'https://www.imdb.com//title/tt0091605/'},
#  {'budget': None,
#   'cumulative_world_gross': 28047963.0,
#   'date': '12 April 2006',
#   'genre': ['Action', 'Drama', 'Romance'],
#   'gross_usa': 14734633.0,
#   'rating': 6.8,
#   'runtime': None,
#   'title': 'Tristan',
#   'url': 'https://www.imdb.com//title/tt0375154/'},
#  {'budget': 15000000.0,
#   'cumulative_world_gross': 39421467.0,
#   'date': '28 August 2009',
#   'genre': ['Horror'],
#   'gross_usa': 33392973.0,
#   'rating': 4.9,
#   'runtime': 105.0,
#   'title': 'Halloween II',
#   'url': 'https://www.imdb.com//title/tt1311067/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': None,
#   'genre': None,
#   'gross_usa': None,
#   'rating': None,
#   'runtime': None,
#   'title': None,
#   'url': 'https://www.imdb.com//title/tt2261331/'},
#  {'budget': 20000000.0,
#   'cumulative_world_gross': 169871719.0,
#   'date': '21 September 2007',
#   'genre': ['Comedy'],
#   'gross_usa': 121463226.0,
#   'rating': 7.6,
#   'runtime': 113.0,
#   'title': 'Superbad',
#   'url': 'https://www.imdb.com//title/tt0829482/'},
#  {'budget': 26000000.0,
#   'cumulative_world_gross': 14821658.0,
#   'date': '16 February 2007',
#   'genre': ['Drama', 'Romance'],
#   'gross_usa': 5463019.0,
#   'rating': 7.5,
#   'runtime': 136.0,
#   'title': 'Little Children',
#   'url': 'https://www.imdb.com//title/tt0404203/'},
#  {'budget': 170000000.0,
#   'cumulative_world_gross': 222104681.0,
#   'date': '30 July 1999',
#   'genre': ['Action', 'Comedy', 'Sci-Fi'],
#   'gross_usa': 113804681.0,
#   'rating': 4.9,
#   'runtime': 106.0,
#   'title': 'Wild Wild West',
#   'url': 'https://www.imdb.com//title/tt0120891/'},
#  {'budget': 30000000.0,
#   'cumulative_world_gross': 8457613.0,
#   'date': '30 June 2011',
#   'genre': ['Comedy', 'Drama'],
#   'gross_usa': 4439201.0,
#   'rating': 7.3,
#   'runtime': 134.0,
#   'title': 'Barneys mange liv',
#   'url': 'https://www.imdb.com//title/tt1423894/'},
#  {'budget': None,
#   'cumulative_world_gross': 24079.0,
#   'date': '29 October 1957',
#   'genre': ['Drama'],
#   'gross_usa': None,
#   'rating': 7.9,
#   'runtime': 118.0,
#   'title': 'Øst for paradis',
#   'url': 'https://www.imdb.com//title/tt0048028/'},
#  {'budget': 1900000.0,
#   'cumulative_world_gross': 144738.0,
#   'date': '11 January 1940',
#   'genre': ['Comedy', 'Drama'],
#   'gross_usa': 144738.0,
#   'rating': 8.1,
#   'runtime': 129.0,
#   'title': 'Mr. Smith kommer til Washington',
#   'url': 'https://www.imdb.com//title/tt0031679/'},
#  {'budget': 11000000.0,
#   'cumulative_world_gross': 78274843.0,
#   'date': '25 September 2014',
#   'genre': ['Drama', 'Fantasy', 'Music'],
#   'gross_usa': 50474843.0,
#   'rating': 6.7,
#   'runtime': 107.0,
#   'title': 'If I Stay',
#   'url': 'https://www.imdb.com//title/tt1355630/'},
#  {'budget': 2800000.0,
#   'cumulative_world_gross': 60922980.0,
#   'date': '6 November 1976',
#   'genre': ['Horror'],
#   'gross_usa': 60922980.0,
#   'rating': 7.5,
#   'runtime': 111.0,
#   'title': 'Tegnet',
#   'url': 'https://www.imdb.com//title/tt0075005/'},
#  {'budget': 11000000.0,
#   'cumulative_world_gross': 16918723.0,
#   'date': '6 May 2005',
#   'genre': ['Biography', 'Drama', 'Romance'],
#   'gross_usa': 10254979.0,
#   'rating': 7.1,
#   'runtime': 118.0,
#   'title': 'Kinsey',
#   'url': 'https://www.imdb.com//title/tt0362269/'},
#  {'budget': 32500000.0,
#   'cumulative_world_gross': 288383523.0,
#   'date': '21 July 2011',
#   'genre': ['Comedy', 'Romance'],
#   'gross_usa': 169106725.0,
#   'rating': 6.8,
#   'runtime': 125.0,
#   'title': 'Brudepiger',
#   'url': 'https://www.imdb.com//title/tt1478338/'},
#  {'budget': 35000000.0,
#   'cumulative_world_gross': 77477008.0,
#   'date': '23 April 2010',
#   'genre': ['Comedy', 'Romance'],
#   'gross_usa': 37490007.0,
#   'rating': 5.3,
#   'runtime': 104.0,
#   'title': 'The Back-up Plan',
#   'url': 'https://www.imdb.com//title/tt1212436/'},
#  {'budget': 11000000.0,
#   'cumulative_world_gross': 11439193.0,
#   'date': '5 August 1994',
#   'genre': ['Comedy', 'Crime', 'Drama'],
#   'gross_usa': 11439193.0,
#   'rating': 6.9,
#   'runtime': 96.0,
#   'title': 'Bossen',
#   'url': 'https://www.imdb.com//title/tt0110955/'},
#  {'budget': 30000000.0,
#   'cumulative_world_gross': 10592180.0,
#   'date': '24 September 2004',
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'gross_usa': 9055921.0,
#   'rating': 5.0,
#   'runtime': None,
#   'title': 'First Daughter',
#   'url': 'https://www.imdb.com//title/tt0361620/'},
#  {'budget': 130000000.0,
#   'cumulative_world_gross': 273339556.0,
#   'date': '9 October 2003',
#   'genre': ['Action', 'Comedy', 'Crime'],
#   'gross_usa': 138608444.0,
#   'rating': 6.6,
#   'runtime': 147.0,
#   'title': 'Bad Boys II',
#   'url': 'https://www.imdb.com//title/tt0172156/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': None,
#   'genre': None,
#   'gross_usa': None,
#   'rating': None,
#   'runtime': None,
#   'title': None,
#   'url': 'https://www.imdb.com//title/tt0133385/'},
#  {'budget': 50000000.0,
#   'cumulative_world_gross': 111069515.0,
#   'date': '7 October 2005',
#   'genre': ['Comedy'],
#   'gross_usa': 80270227.0,
#   'rating': 5.1,
#   'runtime': 104.0,
#   'title': 'The Dukes of Hazzard',
#   'url': 'https://www.imdb.com//title/tt0377818/'},
#  {'budget': 500000.0,
#   'cumulative_world_gross': 10166459.0,
#   'date': '14 July 1989',
#   'genre': ['Action', 'Sci-Fi', 'Thriller'],
#   'gross_usa': 10166459.0,
#   'rating': 5.1,
#   'runtime': 86.0,
#   'title': 'Helten',
#   'url': 'https://www.imdb.com//title/tt0097138/'},
#  {'budget': 125000000.0,
#   'cumulative_world_gross': 546388105.0,
#   'date': '7 July 2000',
#   'genre': ['Action', 'Adventure', 'Thriller'],
#   'gross_usa': 215409889.0,
#   'rating': 6.1,
#   'runtime': 123.0,
#   'title': 'Mission: Impossible 2',
#   'url': 'https://www.imdb.com//title/tt0120755/'},
#  {'budget': 60000000.0,
#   'cumulative_world_gross': 56359980.0,
#   'date': '23 March 2001',
#   'genre': ['Action', 'Crime', 'Drama'],
#   'gross_usa': 24403552.0,
#   'rating': 6.1,
#   'runtime': 120.0,
#   'title': '15 Minutes',
#   'url': 'https://www.imdb.com//title/tt0179626/'},
#  {'budget': 30000000.0,
#   'cumulative_world_gross': 176586701.0,
#   'date': '31 August 2017',
#   'genre': ['Action', 'Comedy', 'Thriller'],
#   'gross_usa': 75468583.0,
#   'rating': 6.9,
#   'runtime': 118.0,
#   'title': "The Hitman's Bodyguard",
#   'url': 'https://www.imdb.com//title/tt1959563/'},
#  {'budget': 11000000.0,
#   'cumulative_world_gross': 34971136.0,
#   'date': '12 October 1981',
#   'genre': ['Adventure', 'Drama', 'Fantasy'],
#   'gross_usa': 34967437.0,
#   'rating': 7.4,
#   'runtime': 140.0,
#   'title': 'Excalibur - kongernes sværd',
#   'url': 'https://www.imdb.com//title/tt0082348/'},
#  {'budget': 4300000.0,
#   'cumulative_world_gross': 43050.0,
#   'date': '26 December 1968',
#   'genre': ['Crime', 'Drama', 'Romance'],
#   'gross_usa': None,
#   'rating': 7.0,
#   'runtime': 102.0,
#   'title': 'Thomas Crown og Co.',
#   'url': 'https://www.imdb.com//title/tt0063688/'},
#  {'budget': 50000000.0,
#   'cumulative_world_gross': 161502194.0,
#   'date': '21 August 2014',
#   'genre': ['Action', 'Adventure', 'Drama'],
#   'gross_usa': 47602194.0,
#   'rating': 5.8,
#   'runtime': 89.0,
#   'title': 'Into the Storm',
#   'url': 'https://www.imdb.com//title/tt2106361/'},
#  {'budget': 15000000.0,
#   'cumulative_world_gross': 216614388.0,
#   'date': '14 April 1989',
#   'genre': ['Comedy', 'Crime'],
#   'gross_usa': 111938388.0,
#   'rating': 6.0,
#   'runtime': 107.0,
#   'title': 'Tvillinger',
#   'url': 'https://www.imdb.com//title/tt0096320/'},
#  {'budget': 25000000.0,
#   'cumulative_world_gross': 27122040.0,
#   'date': '24 March 2011',
#   'genre': ['Action', 'Adventure', 'Drama'],
#   'gross_usa': 19490041.0,
#   'rating': 6.2,
#   'runtime': 114.0,
#   'title': 'The Eagle',
#   'url': 'https://www.imdb.com//title/tt1034389/'},
#  {'budget': 1250000.0,
#   'cumulative_world_gross': 36179290.0,
#   'date': '14 April 1973',
#   'genre': ['Drama', 'Romance'],
#   'gross_usa': 36144000.0,
#   'rating': 7.0,
#   'runtime': 129.0,
#   'title': 'Sidste tango i Paris',
#   'url': 'https://www.imdb.com//title/tt0070849/'},
#  {'budget': 58000000.0,
#   'cumulative_world_gross': 50365377.0,
#   'date': '20 January 2012',
#   'genre': ['Action', 'Adventure', 'Drama'],
#   'gross_usa': 49876377.0,
#   'rating': 5.9,
#   'runtime': None,
#   'title': 'Red Tails',
#   'url': 'https://www.imdb.com//title/tt0485985/'},
#  {'budget': 4500000.0,
#   'cumulative_world_gross': 44793222.0,
#   'date': '24 July 1987',
#   'genre': ['Fantasy', 'Horror'],
#   'gross_usa': 44793222.0,
#   'rating': 6.6,
#   'runtime': 96.0,
#   'title': 'Morderisk mareridt 3',
#   'url': 'https://www.imdb.com//title/tt0093629/'},
#  {'budget': 35000000.0,
#   'cumulative_world_gross': 24470583.0,
#   'date': '29 September 2006',
#   'genre': ['Comedy'],
#   'gross_usa': 17807569.0,
#   'rating': 5.9,
#   'runtime': 100.0,
#   'title': 'School for Scoundrels',
#   'url': 'https://www.imdb.com//title/tt0462519/'},
#  {'budget': 45000000.0,
#   'cumulative_world_gross': 60222298.0,
#   'date': '25 March 2010',
#   'genre': ['Drama', 'Mystery', 'Thriller'],
#   'gross_usa': 15541549.0,
#   'rating': 7.2,
#   'runtime': 128.0,
#   'title': 'Skyggen',
#   'url': 'https://www.imdb.com//title/tt1139328/'},
#  {'budget': 17000000.0,
#   'cumulative_world_gross': 128970716.0,
#   'date': '20 August 2004',
#   'genre': ['Comedy'],
#   'gross_usa': 86058055.0,
#   'rating': 7.0,
#   'runtime': 97.0,
#   'title': 'Mean Girls',
#   'url': 'https://www.imdb.com//title/tt0377092/'},
#  {'budget': 3000000.0,
#   'cumulative_world_gross': 9879971.0,
#   'date': '12 April 2006',
#   'genre': ['Crime', 'Drama'],
#   'gross_usa': 2912606.0,
#   'rating': 7.2,
#   'runtime': 94.0,
#   'title': 'Tsotsi',
#   'url': 'https://www.imdb.com//title/tt0468565/'},
#  {'budget': 14000000.0,
#   'cumulative_world_gross': 171082.0,
#   'date': '10 November 1995',
#   'genre': ['Comedy', 'Drama', 'War'],
#   'gross_usa': 171082.0,
#   'rating': 8.1,
#   'runtime': 170.0,
#   'title': 'Underground',
#   'url': 'https://www.imdb.com//title/tt0114787/'},
#  {'budget': 25000000.0,
#   'cumulative_world_gross': 42013878.0,
#   'date': '26 August 2005',
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'gross_usa': 39053061.0,
#   'rating': 6.5,
#   'runtime': 119.0,
#   'title': 'Fire veninder - et par jeans',
#   'url': 'https://www.imdb.com//title/tt0403508/'},
#  {'budget': 10000000.0,
#   'cumulative_world_gross': 52965.0,
#   'date': '8 July 2011',
#   'genre': ['Horror', 'Mystery', 'Thriller'],
#   'gross_usa': None,
#   'rating': 5.6,
#   'runtime': 89.0,
#   'title': 'The Ward',
#   'url': 'https://www.imdb.com//title/tt1369706/'},
#  {'budget': 25000000.0,
#   'cumulative_world_gross': 94073028.0,
#   'date': '22 January 2016',
#   'genre': ['Comedy'],
#   'gross_usa': 35593113.0,
#   'rating': 5.9,
#   'runtime': 102.0,
#   'title': 'Dirty Grandpa',
#   'url': 'https://www.imdb.com//title/tt1860213/'},
#  {'budget': 7000000.0,
#   'cumulative_world_gross': 19595031.0,
#   'date': '29 July 1988',
#   'genre': ['Fantasy', 'Horror'],
#   'gross_usa': 19595031.0,
#   'rating': 6.5,
#   'runtime': 98.0,
#   'title': 'I gravens dybe stille ro',
#   'url': 'https://www.imdb.com//title/tt0096071/'},
#  {'budget': 130000000.0,
#   'cumulative_world_gross': 185258983.0,
#   'date': '20 March 2009',
#   'genre': ['Action', 'Drama', 'Mystery'],
#   'gross_usa': 107509799.0,
#   'rating': 7.6,
#   'runtime': 162.0,
#   'title': 'Watchmen',
#   'url': 'https://www.imdb.com//title/tt0409459/'},
#  {'budget': 2500000.0,
#   'cumulative_world_gross': None,
#   'date': '18 May 1964',
#   'genre': ['Action', 'Adventure', 'Family'],
#   'gross_usa': None,
#   'rating': 7.3,
#   'runtime': 104.0,
#   'title': 'Jason og det gyldne skind',
#   'url': 'https://www.imdb.com//title/tt0057197/'},
#  {'budget': 48000000.0,
#   'cumulative_world_gross': 16827402.0,
#   'date': '25 December 1994',
#   'genre': ['Adventure', 'Comedy', 'Crime'],
#   'gross_usa': 16827402.0,
#   'rating': 6.1,
#   'runtime': 99.0,
#   'title': 'Alene i byen',
#   'url': 'https://www.imdb.com//title/tt0109190/'},
#  {'budget': 44000000.0,
#   'cumulative_world_gross': 13681765.0,
#   'date': '22 March 1996',
#   'genre': ['Biography', 'Drama', 'History'],
#   'gross_usa': 13681765.0,
#   'rating': 7.1,
#   'runtime': 192.0,
#   'title': 'Nixon',
#   'url': 'https://www.imdb.com//title/tt0113987/'},
#  {'budget': 10900000.0,
#   'cumulative_world_gross': 16607575.0,
#   'date': '13 June 2014',
#   'genre': ['Biography', 'Drama', 'Romance'],
#   'gross_usa': 10726630.0,
#   'rating': 7.4,
#   'runtime': 100.0,
#   'title': 'Belle',
#   'url': 'https://www.imdb.com//title/tt2404181/'},
#  {'budget': None,
#   'cumulative_world_gross': 69932387.0,
#   'date': '6 November 2009',
#   'genre': ['Drama', 'Music'],
#   'gross_usa': 1498210.0,
#   'rating': 8.1,
#   'runtime': 130.0,
#   'title': 'Departures',
#   'url': 'https://www.imdb.com//title/tt1069238/'},
#  {'budget': None,
#   'cumulative_world_gross': 3064818.0,
#   'date': '5 October 2012',
#   'genre': ['Comedy', 'Drama', 'Family'],
#   'gross_usa': 1862086.0,
#   'rating': 7.8,
#   'runtime': 134.0,
#   'title': 'English Vinglish',
#   'url': 'https://www.imdb.com//title/tt2181931/'},
#  {'budget': None,
#   'cumulative_world_gross': 2874.0,
#   'date': '21 February 1983',
#   'genre': ['Adventure', 'Drama'],
#   'gross_usa': None,
#   'rating': 8.1,
#   'runtime': 158.0,
#   'title': 'Fitzcarraldo',
#   'url': 'https://www.imdb.com//title/tt0083946/'},
#  {'budget': 5600000.0,
#   'cumulative_world_gross': 18497446.0,
#   'date': '2 October 2009',
#   'genre': ['Horror', 'Mystery', 'Thriller'],
#   'gross_usa': 27766.0,
#   'rating': 6.5,
#   'runtime': 85.0,
#   'title': '[Rec]²',
#   'url': 'https://www.imdb.com//title/tt1245112/'},
#  {'budget': 70000000.0,
#   'cumulative_world_gross': 56383756.0,
#   'date': '23 September 2011',
#   'genre': ['Action', 'Thriller'],
#   'gross_usa': 25124966.0,
#   'rating': 6.5,
#   'runtime': 116.0,
#   'title': 'Killer Elite',
#   'url': 'https://www.imdb.com//title/tt1448755/'},
#  {'budget': None,
#   'cumulative_world_gross': 28862081.0,
#   'date': '14 June 1991',
#   'genre': ['Comedy', 'Drama', 'Fantasy'],
#   'gross_usa': 28862081.0,
#   'rating': 6.7,
#   'runtime': 95.0,
#   'title': 'Mig og L.A.',
#   'url': 'https://www.imdb.com//title/tt0102250/'},
#  {'budget': 75000000.0,
#   'cumulative_world_gross': 115374915.0,
#   'date': '3 May 2002',
#   'genre': ['Action', 'Drama', 'History'],
#   'gross_usa': 78122718.0,
#   'rating': 7.1,
#   'runtime': 138.0,
#   'title': 'We Were Soldiers',
#   'url': 'https://www.imdb.com//title/tt0277434/'},
#  {'budget': 60000000.0,
#   'cumulative_world_gross': 352194034.0,
#   'date': '26 January 1996',
#   'genre': ['Action', 'Adventure', 'Thriller'],
#   'gross_usa': 106429941.0,
#   'rating': 7.2,
#   'runtime': 130.0,
#   'title': 'Goldeneye',
#   'url': 'https://www.imdb.com//title/tt0113189/'},
#  {'budget': None,
#   'cumulative_world_gross': None,
#   'date': None,
#   'genre': None,
#   'gross_usa': None,
#   'rating': None,
#   'runtime': None,
#   'title': None,
#   'url': 'https://www.imdb.com//title/tt0017136/'},
#  {'budget': 1250000.0,
#   'cumulative_world_gross': 21722776.0,
#   'date': '6 November 1981',
#   'genre': ['Horror', 'Mystery', 'Thriller'],
#   'gross_usa': 21722776.0,
#   'rating': 6.1,
#   'runtime': 87.0,
#   'title': 'Øksemorderen',
#   'url': 'https://www.imdb.com//title/tt0082418/'},
#  {'budget': 90000000.0,
#   'cumulative_world_gross': 100266865.0,
#   'date': '23 February 2007',
#   'genre': ['Drama', 'History', 'Thriller'],
#   'gross_usa': 59952835.0,
#   'rating': 6.7,
#   'runtime': 167.0,
#   'title': 'The Good Shepherd',
#   'url': 'https://www.imdb.com//title/tt0343737/'},
#  {'budget': 8000000.0,
#   'cumulative_world_gross': 59612888.0,
#   'date': '20 September 1985',
#   'genre': ['Comedy', 'Crime', 'Mystery'],
#   'gross_usa': 50612888.0,
#   'rating': 6.9,
#   'runtime': 98.0,
#   'title': "Fletch - hva' var navnet?",
#   'url': 'https://www.imdb.com//title/tt0089155/'},
#  ...]

# %% [markdown]
# ### Making our list into a dataframe, and applying datetime to the releasedate
#
# A dataframe is basically just when a list has both several columns and rows, if there's only one row it's an array.
#
# Remember to comment on the string lengths need to be over 4 characters.

# %%
#df = pd.DataFrame(res).dropna()

#df = df[df['date'].str.len() > 4]

def preparedatetime(dataframe):
    dataframe['datetime'] = pd.to_datetime(dataframe['date'], format = '%d %B %Y')
    dataframe['year'] = dataframe.datetime.dt.year
    dataframe['month'] = dataframe.datetime.dt.month
    dataframe['day'] = dataframe.datetime.dt.day
    return dataframe

#df = preparedatetime(df)

# %%
categories = set()
for i in df["genre"].apply(set).tolist():
    for j in i:
        categories.add(j)
#categories= set(['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family',
#                'Fantasy', 'Film-Noir', 'Game-Show', 'History', 'Horror', 'Music', 'Musical', 'Mystery', 'News',
#                'Reality-TV', 'Romance', 'Sci-Fi', 'Sport', 'Talk-Show', 'Thriller'])
df2 = pd.concat([df, pd.DataFrame(columns=categories)], axis=1)

# %%
def df_dummy(df, col):
    return df.apply(lambda x: col in x["genre"], axis=1)

for i in categories:
    df2[i] = df_dummy(df2, i)
    df2[i] = pd.get_dummies(df2[i], drop_first = True)


df2 = df2.set_index(df['title'])

df2
# Out:
#                                            budget  cumulative_world_gross  \
# title
# 300: Rise of an Empire                110000000.0            3.311141e+08
# Afsløring                              55000000.0            2.140151e+08
# Psycho                                   806947.0            3.200000e+07
# Divergent                              85000000.0            2.888858e+08
# X-Men 2                               110000000.0            4.077115e+08
# Freddy's Dead: The Final Nightmare     11000000.0            3.487203e+07
# Øje for øje                             3700000.0            3.180000e+07
# Christmas Story                         3300000.0            2.061872e+07
# Seabiscuit                             87000000.0            1.483364e+08
# Kubo - den modige samurai              60000000.0            6.992954e+07
# Firefox                                18000000.0            4.670828e+07
# Chocolat                               25000000.0            1.526999e+08
# Happy Feet                            100000000.0            3.843356e+08
# Strømer i børnehaveklassen             15000000.0            2.019577e+08
# Tammy                                  20000000.0            1.003754e+08
# Scary Movie 3                          48000000.0            2.206732e+08
# Vantage Point                          40000000.0            1.511615e+08
# Livsfarlig invasion                    25000000.0            1.160354e+07
# Dræb ikke en sangfugl                   2000000.0            5.991460e+05
# Insidious 2                             5000000.0            1.619193e+08
# The Punisher                           33000000.0            5.470010e+07
# The Darkest Minds                      34000000.0            4.114238e+07
# Søvnløse nætter                        13000000.0            4.936990e+07
# The Long Kiss Goodnight                65000000.0            8.945676e+07
# Fruitvale Station                        900000.0            1.738583e+07
# A.I. Kunstig intelligens                 5 October 2001
# King of California                    12 September 2007
# Life Aquatic                               1 April 2005
# Det' bare mænd                         28 November 1997
# A Cinderella Story                         16 July 2004
# X-Men: First Class                          1 June 2011
# Dogville                                    4 June 2003
# In the Mouth of Madness                 3 February 1995
# Danser med ulve                             10 May 1991
# Jack                                    6 December 1996
# Jeff, Who Lives at Home                     11 May 2012
# Mr. Holmes                                 19 June 2015
# X-Men Origins: Wolverine                  29 April 2009
# Zootropolis                            11 February 2016
# Red State                             30 September 2011
# The Purge: Anarki                     18 September 2014
# Babe: den kække gris kommer til byen    29 January 1999
# Breakdown - det kunne ske for dig         8 August 1997
# Hjælp, det er jul!                     26 November 2004
# Inside Llewyn Davis                        6 March 2014
# Hemmeligheder og løgne                  11 October 1996
# Baby Geniuses                             12 March 1999
# From Hell                               11 January 2002
# Oliver & Co.                            1 December 1989
#
#                                                                genre  \
# title
# 300: Rise of an Empire                             [Action, Fantasy]
# Afsløring                                          [Drama, Thriller]
# Psycho                                   [Horror, Mystery, Thriller]
# Divergent                               [Action, Adventure, Mystery]
# X-Men 2                                   [Action, Sci-Fi, Thriller]
# Freddy's Dead: The Final Nightmare                 [Fantasy, Horror]
# Øje for øje                                                [Western]
# Christmas Story                                     [Comedy, Family]
# Seabiscuit                                   [Drama, History, Sport]
# Kubo - den modige samurai             [Animation, Action, Adventure]
# Firefox                                [Action, Adventure, Thriller]
# Chocolat                                            [Drama, Romance]
# Happy Feet                            [Animation, Adventure, Comedy]
# Strømer i børnehaveklassen                           [Comedy, Crime]
# Tammy                                              [Comedy, Romance]
# Scary Movie 3                                               [Comedy]
# Vantage Point                                 [Action, Crime, Drama]
# Livsfarlig invasion                        [Action, Horror, Mystery]
# Dræb ikke en sangfugl                                 [Crime, Drama]
# Insidious 2                              [Horror, Mystery, Thriller]
# The Punisher                                  [Action, Crime, Drama]
# The Darkest Minds                         [Action, Adventure, Drama]
# Søvnløse nætter                                             [Horror]
# The Long Kiss Goodnight                       [Action, Crime, Drama]
# Fruitvale Station                        [Biography, Drama, Romance]
# ATM                                               [Horror, Thriller]
# Camp X-Ray                                              [Drama, War]
# The Wedding Planner                                [Comedy, Romance]
# Fright Night                                        [Comedy, Horror]
# Star Trek                                [Action, Adventure, Sci-Fi]
# ...                                                              ...
# Bad Company                              [Action, Adventure, Comedy]
# The Sound of Music                        [Biography, Drama, Family]
# Anaconda                                 [Action, Adventure, Horror]
# Orkidé-tyven                                         [Comedy, Drama]
# Sheriffen skyder på det hele                       [Comedy, Western]
# Paranormal Activity                      [Horror, Mystery, Thriller]
# A.I. Kunstig intelligens                             [Drama, Sci-Fi]
# King of California                                   [Comedy, Drama]
# Life Aquatic                             [Action, Adventure, Comedy]
# Det' bare mænd                                       [Comedy, Drama]
# A Cinderella Story                         [Comedy, Family, Romance]
# X-Men: First Class                       [Action, Adventure, Sci-Fi]
# Dogville                                              [Crime, Drama]
# In the Mouth of Madness                     [Drama, Horror, Mystery]
# Danser med ulve                          [Adventure, Drama, Western]
# Baby Geniuses                                 0      0          0        0
# From Hell                                     0      0          0        0
# Oliver & Co.                                  1      0          0        0
#
#                                       Musical  Family  Action  Sport
# title
# 300: Rise of an Empire                      0       0       1      0
# Afsløring                                   0       0       0      0
# Psycho                                      0       0       0      0
# Divergent                                   0       0       1      0
# X-Men 2                                     0       0       1      0
# Freddy's Dead: The Final Nightmare          0       0       0      0
# Øje for øje                                 0       0       0      0
# Christmas Story                             0       1       0      0
# Seabiscuit                                  0       0       0      1
# Kubo - den modige samurai                   0       0       1      0
# Firefox                                     0       0       1      0
# Chocolat                                    0       0       0      0
# Happy Feet                                  0       0       0      0
# Strømer i børnehaveklassen                  0       0       0      0
# Tammy                                       0       0       0      0
# Scary Movie 3                               0       0       0      0
# Vantage Point                               0       0       1      0
# Livsfarlig invasion                         0       0       1      0
# Dræb ikke en sangfugl                       0       0       0      0
# Insidious 2                                 0       0       0      0
# The Punisher                                0       0       1      0
# The Darkest Minds                           0       0       1      0
# Søvnløse nætter                             0       0       0      0
# The Long Kiss Goodnight                     0       0       1      0
# Fruitvale Station                           0       0       0      0
# ATM                                         0       0       0      0
# Camp X-Ray                                  0       0       0      0
# The Wedding Planner                         0       0       0      0
# Fright Night                                0       0       0      0
# Star Trek                                   0       0       1      0
# ...                                       ...     ...     ...    ...
# Bad Company                                 0       0       1      0
# The Sound of Music                          0       1       0      0
# Anaconda                                    0       0       1      0
# Orkidé-tyven                                0       0       0      0
# Sheriffen skyder på det hele                0       0       0      0
# Paranormal Activity                         0       0       0      0
# A.I. Kunstig intelligens                    0       0       0      0
# King of California                          0       0       0      0
# Life Aquatic                                0       0       1      0
# Det' bare mænd                              0       0       0      0
# A Cinderella Story                          0       1       0      0
# X-Men: First Class                          0       0       1      0
# Dogville                                    0       0       0      0
# In the Mouth of Madness                     0       0       0      0
# Danser med ulve                             0       0       0      0
# Jack                                        0       0       0      0
# Jeff, Who Lives at Home                     0       0       0      0
# Mr. Holmes                                  0       0       0      0
# X-Men Origins: Wolverine                    0       0       1      0
# Zootropolis                                 0       0       0      0
# Red State                                   0       0       1      0
# The Purge: Anarki                           0       0       1      0
# Babe: den kække gris kommer til byen        0       0       0      0
# Breakdown - det kunne ske for dig           0       0       0      0
# Hjælp, det er jul!                          0       1       0      0
# Inside Llewyn Davis                         0       0       0      0
# Hemmeligheder og løgne                      0       0       0      0
# Baby Geniuses                               0       1       0      0
# From Hell                                   0       0       0      0
# Oliver & Co.                                0       0       0      0
#
# [3819 rows x 34 columns]

# %% [markdown]
# ### Descriptive statistics

# %% [markdown]
# fig, ax = plt.subplots(figsize = (10, 4.5))
#
# ax.set_xlim([0,100])
# ax.set_ylim([0,0.05]) #5.2.1
#
# for c in df2["budget"].unique():
#     df_ = df2[df2["budget"] == c]
#     sns.kdeplot(df_["cumulative_world_gross"], label=c, ax=ax)
#
# ax.set_title('Age densities in classes')
# ax.set_xlabel('Age')
# ax.set_ylabel('Class')
# ax.title.set_fontsize(20)
# ax.xaxis.label.set_fontsize(16)
# ax.yaxis.label.set_fontsize(16)
#
#
# ax2 = plt.axes([0.55, 0.6, 0.3, 0.2])
# ax.legend(bbox_to_anchor=(1.2, 1.05))
# sns.barplot(x='class', y='survived', data=titanic)

# %% [markdown]
# # Creating a gradient descent optimization of the weights
#
# First we import all the necessary packages for this step.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import mean_squared_error as mse

# %%
#X = df2.drop('cumulative_world_gross','date', 'genre','title', 'url', 'datetime', 'year', 'month', 'day', axis = 1)
#categoriess= np.array(categories)

X = df2[['budget', 'rating', 'runtime', *list(categories)]]
X2 = df2[['rating', 'runtime', *list(categories)]]
y = df2['cumulative_world_gross']
y2 = df2['cumulative_world_gross']/df2['budget']

from sklearn.model_selection import train_test_split

#X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.5, random_state=1)
#Søljeplot, genre mean rating, mean brøk, hvad sker der

# %% [markdown]
# ### Creating a scaler from our train data and implement this on the test data

# %% [markdown]
# from sklearn.preprocessing import StandardScaler, PolynomialFeatures
# norm_scaler = StandardScaler().fit(X_train)
# X_train = norm_scaler.transform(X_train)
# X_test = norm_scaler.transform(X_test)
#
# #Her har vi brugt normalisering i stedet for standardisering

# %% [markdown]
# ### Computing prediction errors given the target, features and weights

# %% [markdown]
# def net_input(X_, w_):
#     ''' Computes the matrix product between X and w. Note that
#     X is assumed not to contain a bias/intercept column.'''
#     return np.dot(X_, w_[1:]) + w_[0]   # We have to add w_[0] separately because this is the constant term. We could also have added a constant term (columns of 1's to X_ and multipliced it to all of w_)
#
# def compute_error(y_, X_, w_):
#     return y_ - net_input(X_, w_)

# %% [markdown]
# ### Updating the weights given the prediction error

# %% [markdown]
# def update_weight(y_, X_, w_, eta):
#     error = compute_error(y_, X_, w_)
#     w_[1:] += eta * (X_.T.dot(error))
#     w_[0] += eta * (error).sum()

# %% [markdown]
# ### Make a function to compute the mean squared error. Alter the loop so it makes 100 iterations and computes the MSE for test and train after each iteration.

# %% [markdown]
# #from sklearn.metrics import mean_squared_error as mse
#
# def MSE(y_, X_, w_):
#     error_squared = compute_error(y_, X_, w_)**2
#     return error_squared.sum() / len(y_)
#
# def rmse(y_, X_, w_):
#     return np.sqrt(MSE(y_, X_, w_))
#
#
# w = np.zeros(X.shape[1]+1)
#
# rmse_train = [rmse(y_train, X_train, w)]
# rmse_test = [rmse(y_test, X_test, w)]
# rmseDESCENT = [rmse(y, X, w)]
# for i in range(100):
#     update_weight(y_train, X_train, w, 10**-20)
#
#     rmse_train.append(rmse(y_train, X_train, w))
#     rmse_test.append(rmse(y_test, X_test, w))
#
#
#    # brug rmse

# %% [markdown]
# pd.Series(rmse_train).plot(label='train')
# pd.Series(rmse_test).plot(label='test').legend()
# #brug sckitlearn

# %% [markdown]
# ### Checking our optimal weights to see the correlation

# %% [markdown]
# Gradient_Descent_coefficients = w

# %% [markdown]
# Gradient_Descent_coefficients

# %% [markdown]
# ### Machine learning, OLS
# From computing the descriptive statistics of RMSE for the train data on the test and validation data we can conclude we can split the train data and use this to fit the model. This is because the descriptive statistics are quite similar and we therefore presume our model i generalizing enough. (Balanced).

# %%
#X = df2[['budget', 'gross_usa', 'rating', 'runtime', *list(categories)]]

def rmse(y_pred, y_true):
    return np.sqrt(mse(y_pred, y_true))

output=[]

for random_state in range(10):
    X_dev, X_test, y_dev, y_test = train_test_split(X, y, test_size=1/3, random_state=1)
    X_train, X_val, y_train, y_val = train_test_split(X_dev, y_dev, test_size=1/2, random_state=1)
    
    reg = LinearRegression().fit(X_train, y_train)
    reg.predict(X_test)
    
    output.append([rmse(reg.predict(X_val), y_val),
                  rmse(reg.predict(X_test), y_test)])
    
print(pd.DataFrame(output, columns=['test', 'validation']))

print(pd.DataFrame(output, columns=['test', 'validation']).describe())
# Out:
#            test    validation
# 0  4.928110e+07  5.984905e+07
# 1  4.928110e+07  5.984905e+07
# 2  4.928110e+07  5.984905e+07
# 3  4.928110e+07  5.984905e+07
# 4  4.928110e+07  5.984905e+07
# 5  4.928110e+07  5.984905e+07
# 6  4.928110e+07  5.984905e+07
# 7  4.928110e+07  5.984905e+07
# 8  4.928110e+07  5.984905e+07
# 9  4.928110e+07  5.984905e+07
#                test    validation
# count  1.000000e+01  1.000000e+01
# mean   4.928110e+07  5.984905e+07
# std    7.853602e-09  7.853602e-09
# min    4.928110e+07  5.984905e+07
# 25%    4.928110e+07  5.984905e+07
# 50%    4.928110e+07  5.984905e+07
# 75%    4.928110e+07  5.984905e+07
# max    4.928110e+07  5.984905e+07

# %%
from sklearn.model_selection import KFold
kfolds = KFold(n_splits=10) #Splits the data 10 times into evenly sized bins. 
folds = list()

lambdas = np.logspace(5,10,20)
# outer loop: lambdas
rmseCV = []
perform = []

for lambda_ in lambdas:    
    # inner loop: folds. For each of the folds (Splits),
    rmseCV_ = []    
    for train_idx, val_idx in kfolds.split(X_dev, y_dev):        
        # train model and compute MSE on test fold
        pipe_lassoCV = make_pipeline(ColumnTransformer(
                                    [("Continous", make_pipeline(
                                         StandardScaler(),
                                         PolynomialFeatures()
                                     ), [0,2]), 
                                      ("", 'passthrough', [i for i in range(3, X.shape[1])])
                                     ]),
                                    LinearRegression())
        X_train, y_train, = X_dev.iloc[train_idx], y_dev[train_idx] #Selection where we throw in the indices and take out the data
        X_val, y_val = X_dev.iloc[val_idx], y_dev[val_idx] 
        pipe_lassoCV.fit(X_train, y_train)  #Fit the model on the training data, estimation
        rmseCV_.append(rmse(pipe_lassoCV.predict(X_val), y_val))   #Apply the model to the validation data and store it in an empty list
    #y_val_pred = pipe_lassoCV.predict(X_val)
    #y_train_pred = pipe_lassoCV.predict(X_train)
    #y_test_pred = pipe_lassoCV.predict(X_test)
    #perform.append(mse(y_pred, y_val))
    # store result    
    rmseCV.append(sum(rmseCV_)/len(rmseCV_)) 
    
# convert to DataFrame
lambdaCV = pd.DataFrame(rmseCV, index=lambdas)

lambdaCV

optimal_lambda = lambdaCV.mean(axis=1).nsmallest(1)
optimal_lambda
# Out:
# 100000.0    1.124888e+08
# dtype: float64

# %% [markdown]
# Lasso_coefficients = reg.coef_
# Lasso_intercept = reg.intercept_
# print(Lasso_coefficients)
# print(Lasso_intercept)

# %%
y_val_pred = pipe_lassoCV.predict(X_val)
y_train_pred = pipe_lassoCV.predict(X_train)
y_test_pred = pipe_lassoCV.predict(X_test)
    #perform.append(mse(y_pred, y_val))

# %% [markdown]
# ## Machine learning, OLS with Lasso
#
# From computing the descriptive statistics of RMSE for the train data on  the test and validation data we can conclude we can split the train data and use this to fit the model. This is because the descriptive statistics are quite similar and we therefore presume our model i generalizing enough. (Balanced).

# %%
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %% [markdown]
# For the genres we have dummy variables, which shouldn't be scaled or made into polynomial features. For this reason our piline only adds these attributes to the first NUMMER columns and only creates the lasso for all of the features.

# %%
from sklearn.model_selection import KFold
kfolds = KFold(n_splits=10) #Splits the data 10 times into evenly sized bins. 
folds = list()

lambdas = np.logspace(5,10,20)
# outer loop: lambdas
rmseCV = []
perform = []

for lambda_ in lambdas:    
    # inner loop: folds. For each of the folds (Splits),
    rmseCV_ = []    
    for train_idx, val_idx in kfolds.split(X_dev, y_dev):        
        # train model and compute MSE on test fold
        pipe_lassoCV = make_pipeline(ColumnTransformer(
                                    [("Continous", make_pipeline(
                                         StandardScaler(),
                                         PolynomialFeatures()
                                     ), [0,2]), 
                                      ("", 'passthrough', [i for i in range(3, X.shape[1])])
                                     ]),
                                    Lasso(alpha=lambda_, random_state=1))
        X_train, y_train, = X_dev.iloc[train_idx], y_dev[train_idx] #Selection where we throw in the indices and take out the data
        X_val, y_val = X_dev.iloc[val_idx], y_dev[val_idx] 
        pipe_lassoCV.fit(X_train, y_train)  #Fit the model on the training data, estimation
        rmseCV_.append(rmse(pipe_lassoCV.predict(X_val), y_val))   #Apply the model to the validation data and store it in an empty list
    #y_val_pred = pipe_lassoCV.predict(X_val)
    #y_train_pred = pipe_lassoCV.predict(X_train)
    #y_test_pred = pipe_lassoCV.predict(X_test)
    #perform.append(mse(y_pred, y_val))
    # store result    
    rmseCV.append(sum(rmseCV_)/len(rmseCV_)) 
    
# convert to DataFrame
lambdaCV = pd.DataFrame(rmseCV, index=lambdas)

lambdaCV

optimal_lambda = lambdaCV.mean(axis=1).nsmallest(1)
optimal_lambda


#modellen lærer om. virkeligheden og justerer til eget data, hvordan renser vi usikerheden væk
# Out:
# 615848.211066    1.123793e+08
# dtype: float64

# %%
print('Coefficients: \n', reg.coef_) 
print('Intercept: \n', reg.intercept_) 
# variance score: 1 means perfect prediction 
print('Variance score: {}'.format(reg.score(X_test, y_test)))

## plotting residual errors in training data 
plt.scatter(reg.predict(X_train), reg.predict(X_train) - y_train, 
            color = "green", s = 10, label = 'Train data') 
  
## plotting residual errors in test data 
plt.scatter(reg.predict(X_test), reg.predict(X_test) - y_test, 
            color = "blue", s = 10, label = 'Test data') 
  
## plotting line for zero residual error 
plt.hlines(y = 0, xmin = 0, xmax = 50*10**8, linewidth = 2) 
  
## plotting legend 
plt.legend(loc = 'upper right') 
  
## plot title 
plt.title("Residual errors") 
  
plt.xlabel('Predicted value')
plt.ylabel('Residual')
## function to show plot 
plt.show()
# Out:
# Coefficients:
#  [ 8.72698446e-01  2.01474801e+00  1.80827149e+06 -4.67397540e+04
#   1.20146155e+06  4.41929394e+06  7.89202117e+06 -1.06744999e+07
#   8.18720665e+06 -9.99962253e+05  3.89719294e+06  6.52458220e+06
#   2.17023163e+07 -9.86064349e+06  3.62236089e+07  2.21270053e+07
#  -6.73696450e+06  1.53023227e+07  6.85436414e+06 -1.57317950e+06
#   6.01467234e+06  5.39456356e+07 -1.97697679e+07 -9.60688172e+06
#  -2.30113501e+07]
# Intercept:
#  -40917203.55770601
# Variance score: 0.8982672037304885

# %%
Lasso_coefficients = reg.coef_
Lasso_intercept = reg.intercept_


print(Lasso_coefficients)
print(Lasso_intercept)

#Zip eller plot dem sammen
# Out:
# [ 8.72698446e-01  2.01474801e+00  1.80827149e+06 -4.67397540e+04
#   1.20146155e+06  4.41929394e+06  7.89202117e+06 -1.06744999e+07
#   8.18720665e+06 -9.99962253e+05  3.89719294e+06  6.52458220e+06
#   2.17023163e+07 -9.86064349e+06  3.62236089e+07  2.21270053e+07
#  -6.73696450e+06  1.53023227e+07  6.85436414e+06 -1.57317950e+06
#   6.01467234e+06  5.39456356e+07 -1.97697679e+07 -9.60688172e+06
#  -2.30113501e+07]
# -40917203.55770601

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, test_scores = \
    learning_curve(estimator=pipe_lassoCV,
                   X=X_train,
                   y=y_train,
                   train_sizes=np.arange(0.2, 1, .01),
                   scoring='neg_mean_squared_error',                 
                   cv=3)
    
mse_ = pd.DataFrame({'Train':-train_scores.mean(axis=1),
                     'Test':-test_scores.mean(axis=1)})\
        .set_index(pd.Index(train_sizes,name='sample size'))    
print(mse_.head(3))
# Out:
#                     Train          Test
# sample size
# 305          2.479072e+16  2.740801e+16
# 320          2.418055e+16  2.739011e+16
# 336          2.443643e+16  2.736604e+16

# %%
f_learn, ax = plt.subplots(figsize=(10,4))
ax.fill_between(train_sizes,
                -test_scores.mean(1) + test_scores.std(1)*1.96,
                -test_scores.mean(1) - test_scores.std(1)*1.96, 
                alpha=0.25, label ='Test', color='blue')

ax.fill_between(train_sizes,
                -train_scores.mean(1) + train_scores.std(1)*1.96,
                -train_scores.mean(1) - train_scores.std(1)*1.96, 
                alpha=0.25, label='Train', color='orange')
ax.set_ylabel('Mean squared error')
ax.set_yscale('log')
ax.legend()

# %%
from sklearn.model_selection import validation_curve

train_scores, test_scores = \
    validation_curve(estimator=pipe_lassoCV,
                     X=X_dev,
                     y=y_dev,
                     param_name='lasso__alpha',
                     param_range=lambdas,
                     scoring='neg_mean_squared_error',                 
                     cv=3)

mse_score = pd.DataFrame({'Train':-train_scores.mean(axis=1),
                          'Validation':-test_scores.mean(axis=1),
                          'lambda':lambdas})\
              .set_index('lambda')   
print(mse_score.Validation.nsmallest(1))
# Out:
# lambda
# 615848.211066    1.318634e+16
# Name: Validation, dtype: float64

# %%
mse_score.plot(logx=True, logy=True)

#overfitter fordi den er bedre på train end validation

# %% [markdown]
# plt.scatter(y_train_pred,  y_train_pred - y_train,
#              c='steelblue', marker='o', edgecolor='white',
#              label='Training data')
# plt.scatter(y_test_pred,  y_test_pred - y_test,
#              c='limegreen', marker='s', edgecolor='white',
#             label='Test data')
# plt.xlabel('Predicted values')
# plt.ylabel('Residuals')
# plt.legend(loc='upper left')
# plt.hlines(y=0, xmin=-10, xmax=50, color='black', lw=2)
# plt.xlim([-10, 50])
# plt.show()

# %% [markdown]
# ## Prediction of the cumulative gross in relation to the budget

# %%
def rmse(y_pred, y_true):
    return np.sqrt(mse(y_pred, y_true))

output=[]

for random_state in range(10):
    X_dev, X_test, y_dev, y_test = train_test_split(X, y2, test_size=1/3, random_state=1)
    X_train, X_val, y_train, y_val = train_test_split(X_dev, y_dev, test_size=1/2, random_state=1)
    
    reg = LinearRegression().fit(X_train, y_train)
    reg.predict(X_test)
    
    output.append([rmse(reg.predict(X_val), y_val),
                  rmse(reg.predict(X_test), y_test)])
    
print(pd.DataFrame(output, columns=['test', 'validation']))

print(pd.DataFrame(output, columns=['test', 'validation']).describe())
# Out:
#            test  validation
# 0  53698.270616  116.099444
# 1  53698.270616  116.099444
# 2  53698.270616  116.099444
# 3  53698.270616  116.099444
# 4  53698.270616  116.099444
# 5  53698.270616  116.099444
# 6  53698.270616  116.099444
# 7  53698.270616  116.099444
# 8  53698.270616  116.099444
# 9  53698.270616  116.099444
#                test    validation
# count     10.000000  1.000000e+01
# mean   53698.270616  1.160994e+02
# std        0.000000  1.497956e-14
# min    53698.270616  1.160994e+02
# 25%    53698.270616  1.160994e+02
# 50%    53698.270616  1.160994e+02
# 75%    53698.270616  1.160994e+02
# max    53698.270616  1.160994e+02

# %%
from sklearn.model_selection import KFold
kfolds = KFold(n_splits=10) #Splits the data 10 times into evenly sized bins. 
folds = list()

lambdas = np.logspace(5,10,20)
# outer loop: lambdas
rmseCV = []
perform = []

for lambda_ in lambdas:    
    # inner loop: folds. For each of the folds (Splits),
    rmseCV_ = []    
    for train_idx, val_idx in kfolds.split(X_dev, y_dev):        
        # train model and compute MSE on test fold
        pipe_lassoCV = make_pipeline(ColumnTransformer(
                                    [("Continous", make_pipeline(
                                         StandardScaler(),
                                         PolynomialFeatures()
                                     ), [0,1]), 
                                      ("", 'passthrough', [i for i in range(2, X.shape[1])])
                                     ]),
                                    Lasso(alpha=lambda_, random_state=1))
        X_train, y_train, = X_dev.iloc[train_idx], y_dev[train_idx] #Selection where we throw in the indices and take out the data
        X_val, y_val = X_dev.iloc[val_idx], y_dev[val_idx] 
        pipe_lassoCV.fit(X_train, y_train)  #Fit the model on the training data, estimation
        rmseCV_.append(rmse(pipe_lassoCV.predict(X_val), y_val))   #Apply the model to the validation data and store it in an empty list
    #y_val_pred = pipe_lassoCV.predict(X_val)
    #y_train_pred = pipe_lassoCV.predict(X_train)
    #y_test_pred = pipe_lassoCV.predict(X_test)
    #perform.append(mse(y_pred, y_val))
    # store result    
    rmseCV.append(sum(rmseCV_)/len(rmseCV_)) 
    
# convert to DataFrame
lambdaCV = pd.DataFrame(rmseCV, index=lambdas)

lambdaCV

optimal_lambda = lambdaCV.mean(axis=1).nsmallest(1)
optimal_lambda
# Out:
# 100000.0    12810.612526
# dtype: float64

# %%
X2
# Out:
#                                       rating  runtime  War  Mystery  Horror  \
# title
# 300: Rise of an Empire                   6.2    102.0    0        0       0
# Afsløring                                6.1    128.0    0        0       0
# Psycho                                   8.5    109.0    0        1       1
# Divergent                                6.7    139.0    0        1       0
# X-Men 2                                  7.4    134.0    0        0       0
# Freddy's Dead: The Final Nightmare       4.9     89.0    0        0       1
# Øje for øje                              7.9    135.0    0        0       0
# Christmas Story                          8.0     94.0    0        0       0
# Seabiscuit                               7.3    140.0    0        0       0
# Kubo - den modige samurai                7.8    101.0    0        0       0
# Firefox                                  5.9    136.0    0        0       0
# Chocolat                                 7.2    121.0    0        0       0
# Happy Feet                               6.4    108.0    0        0       0
# Strømer i børnehaveklassen               6.1    111.0    0        0       0
# Tammy                                    4.9     97.0    0        0       0
# Scary Movie 3                            5.5     84.0    0        0       0
# Vantage Point                            6.6     90.0    0        0       0
# Livsfarlig invasion                      6.1    101.0    0        1       1
# Dræb ikke en sangfugl                    8.3    129.0    0        0       0
# Insidious 2                              6.6    106.0    0        1       1
# The Punisher                             6.4    124.0    0        0       0
# The Darkest Minds                        5.7    104.0    0        0       0
# Søvnløse nætter                          5.7     93.0    0        0       1
# The Long Kiss Goodnight                  6.8    121.0    0        0       0
# Fruitvale Station                        7.5     85.0    0        0       0
# ATM                                      4.7     90.0    0        0       1
# Camp X-Ray                               6.9    117.0    1        0       0
# The Wedding Planner                      5.3    103.0    0        0       0
# Fright Night                             6.3    106.0    0        0       1
# Star Trek                                7.9    127.0    0        0       0
# ...                                      ...      ...  ...      ...     ...
# Bad Company                              5.6    116.0    0        0       0
# The Sound of Music                       8.0    172.0    0        0       0
# Anaconda                                 4.8     89.0    0        0       1
# Orkidé-tyven                             7.7    115.0    0        0       0
# Sheriffen skyder på det hele             7.7     93.0    0        0       0
# Paranormal Activity                      6.3     86.0    0        1       1
# A.I. Kunstig intelligens                 7.2    146.0    0        0       0
# King of California                       6.6     93.0    0        0       0
# Life Aquatic                             7.3    119.0    0        0       0
# Det' bare mænd                           7.2     91.0    0        0       0
# A Cinderella Story                       5.9     95.0    0        0       0
# X-Men: First Class                       7.7    131.0    0        0       0
# Dogville                                 8.0    178.0    0        0       0
# In the Mouth of Madness                  7.2     95.0    0        1       1
# Danser med ulve                          8.0    181.0    0        0       0
# Jack                                     5.8    113.0    0        0       0
# Jeff, Who Lives at Home                  6.5     83.0    0        0       0
# Mr. Holmes                               6.9    104.0    0        1       0
# X-Men Origins: Wolverine                 6.6    107.0    0        0       0
# Zootropolis                              8.0    108.0    0        0       0
# From Hell                                  0        0      0         1      0
# Oliver & Co.                               1        0      0         0      0
#
#                                       ...  Film-Noir  Western  Adventure  \
# title                                 ...
# 300: Rise of an Empire                ...          0        0          0
# Afsløring                             ...          0        0          0
# Psycho                                ...          0        0          0
# Divergent                             ...          0        0          1
# X-Men 2                               ...          0        0          0
# Freddy's Dead: The Final Nightmare    ...          0        0          0
# Øje for øje                           ...          0        1          0
# Christmas Story                       ...          0        0          0
# Seabiscuit                            ...          0        0          0
# Kubo - den modige samurai             ...          0        0          1
# Firefox                               ...          0        0          1
# Chocolat                              ...          0        0          0
# Happy Feet                            ...          0        0          1
# Strømer i børnehaveklassen            ...          0        0          0
# Tammy                                 ...          0        0          0
# Scary Movie 3                         ...          0        0          0
# Vantage Point                         ...          0        0          0
# Livsfarlig invasion                   ...          0        0          0
# Dræb ikke en sangfugl                 ...          0        0          0
# Insidious 2                           ...          0        0          0
# The Punisher                          ...          0        0          0
# The Darkest Minds                     ...          0        0          1
# Søvnløse nætter                       ...          0        0          0
# The Long Kiss Goodnight               ...          0        0          0
# Fruitvale Station                     ...          0        0          0
# ATM                                   ...          0        0          0
# Camp X-Ray                            ...          0        0          0
# The Wedding Planner                   ...          0        0          0
# Fright Night                          ...          0        0          0
# Star Trek                             ...          0        0          1
# ...                                   ...        ...      ...        ...
# Bad Company                           ...          0        0          1
# The Sound of Music                    ...          0        0          0
# Anaconda                              ...          0        0          1
# Orkidé-tyven                          ...          0        0          0
# Sheriffen skyder på det hele          ...          0        1          0
# Paranormal Activity                   ...          0        0          0
# A.I. Kunstig intelligens              ...          0        0          0
# King of California                    ...          0        0          0
# Life Aquatic                          ...          0        0          1
# Det' bare mænd                        ...          0        0          0
# A Cinderella Story                    ...          0        0          0
# X-Men: First Class                    ...          0        0          1
# Dogville                              ...          0        0          0
# In the Mouth of Madness               ...          0        0          0
# Danser med ulve                       ...          0        1          1
# Jack                                  ...          0        0          0
# Jeff, Who Lives at Home               ...          0        0          0
# Mr. Holmes                            ...          0        0          0
# X-Men Origins: Wolverine              ...          0        0          1
# Zootropolis                           ...          0        0          1
# Red State                             ...          0        0          0
# The Purge: Anarki                     ...          0        0          0
# Babe: den kække gris kommer til byen  ...          0        0          1
# Breakdown - det kunne ske for dig     ...          0        0          0
# Hjælp, det er jul!                    ...          0        0          0
# Inside Llewyn Davis                   ...          0        0          0
# Hemmeligheder og løgne                ...          0        0          0
# Baby Geniuses                         ...          0        0          0
# From Hell                             ...          0        0          0
# Oliver & Co.                          ...          0        0          1
#
#                                       Drama  Biography  Romance  Musical  \
# title
# 300: Rise of an Empire                    0          0        0        0
# Afsløring                                 1          0        0        0
# Psycho                                    0          0        0        0
# Divergent                                 0          0        0        0
# X-Men 2                                   0          0        0        0
# Freddy's Dead: The Final Nightmare        0          0        0        0
# Øje for øje                               0          0        0        0
# Christmas Story                           0          0        0        0
# Seabiscuit                                1          0        0        0
# Kubo - den modige samurai                 0          0        0        0
# Firefox                                   0          0        0        0
# Chocolat                                  1          0        1        0
# Happy Feet                                0          0        0        0
# Paranormal Activity                        0       0      0
# A.I. Kunstig intelligens                   0       0      0
# King of California                         0       0      0
# Life Aquatic                               0       1      0
# Det' bare mænd                             0       0      0
# A Cinderella Story                         1       0      0
# X-Men: First Class                         0       1      0
# Dogville                                   0       0      0
# In the Mouth of Madness                    0       0      0
# Danser med ulve                            0       0      0
# Jack                                       0       0      0
# Jeff, Who Lives at Home                    0       0      0
# Mr. Holmes                                 0       0      0
# X-Men Origins: Wolverine                   0       1      0
# Zootropolis                                0       0      0
# Red State                                  0       1      0
# The Purge: Anarki                          0       1      0
# Babe: den kække gris kommer til byen       0       0      0
# Breakdown - det kunne ske for dig          0       0      0
# Hjælp, det er jul!                         1       0      0
# Inside Llewyn Davis                        0       0      0
# Hemmeligheder og løgne                     0       0      0
# Baby Geniuses                              1       0      0
# From Hell                                  0       0      0
# Oliver & Co.                               0       0      0
#
# [3819 rows x 23 columns]

# %% [markdown]
# ## Notes for machine learning
#
# Use predictions. But be careful, look at decisions when it is launced only.
#
#
# How predictive are these features for estimating future earnings? You can say what happens to gross whne I have the feature and exclude it. What happens?
#
# What model should we use, try the ols or the
#
# run the lasso and allow the regularization - check whether the hyperparameter is really close to ols and check to see if all features are included. Check to see if the lasso is redundent for our case. If the lasso doesn't exclude any features and lambda is like ols you could just use ols.
#
# Remember to comment on bias. Is there something correlated with the error term?
#
# Our data is continous which is why we've used the root squared mean error (RMSE) as our accuracy measure.
#
# 1.
#
# The ridge and lasso determines lasso, when we start estimating we could fix it at a certain order but could also make it a hyperparameter. We optimize over these lambdas at our validation set. First we split the data in order to have an honest. the more data you have the less you need for testing. we've chosen a distribution of blabla. With polynomial transformation.
#
# 2.
# After we have the data split we make a model. We take all of our polynomial, scaling and our supervised learning model to make it a pipeline. It gives a clean overview of what we've done.
#
# 3.
#
# We have build a pipeline. If we have hyperparameters then we want to optimise these. we split the development into one to fit and one to validate. Subdatasets. We take the one that performs best on the validation data. Because we believe this one will perform best on the test data.
#
# We estimate the model with the optimal hyperparameter and can go to the test data now.
#
# USE CV, Cross validation.
#
# Use cv to find the optimal hyperparameters. Cross validation is the loop thing in range 10. So we take the average best on all of the validation sets. This is to avoid that we've just got a lucky draw. USE CV PLEASE AMALIE TAG DIG SAMMEN. We use it in the inner way to find the hyperparameter. We can also use it in the outer way on the whole set. So we also rotate which has to be the test data each time. So the split of test and development and afterwards in the inner level for the train and validation on the development data. HYPERPARAMETERS ARE ON THE INNER LEVEL.
#
# REMEMBER TO CHECK FOR TIME SERIES
#
# 5. Now we fit the model using all the data in the development set. Afterwards you test it on the test set.
#
# If you want to say these features add this much? Then you should just plot the distributions and comment on the similarity.
#
# If we asume all are independt and can sample them statically. For each of the test we use the non test data to make our model 10 times. Then we have do this with and without the features we're testing for.
#
#
#
# A comprehensive guide for how to earn money on movies in hollywood, trying to see which feautures affect the gross most and if you want a surtain audience you should make this genre.

# %% [markdown]
# ## Code for plots

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import seaborn as sns

plt.style.use('ggplot')
# %matplotlib inline

SMALL_SIZE = 16
MEDIUM_SIZE = 18
BIGGER_SIZE = 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
